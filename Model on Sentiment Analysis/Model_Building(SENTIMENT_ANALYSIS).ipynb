# %%
# %%time
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style='darkgrid')
from matplotlib import style
#sta matplotlib to inline and displays graphs below the corresponding cell.
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set(style='whitegrid', palette='muted', font_scale=1.2)
HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]
sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

#Tensorflow Keras
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional,Activation, Dense, Dropout, Embedding, Flatten, Conv1D, MaxPooling1D, LSTM
from tensorflow.keras import utils
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical


# nltk
import nltk
from nltk.corpus import stopwords
from gensim.models import Word2Vec
from  nltk.stem import SnowballStemmer

# Word2vec
import gensim

# Utility
import re
from collections import Counter
import logging
import time
import pickle
import itertools



print(f"Above Libraries were successfully loaded")
# Out:
# Above Libraries were successfully loaded
# Wall time: 5.95 s

# %%
df=pd.read_csv(r"C:\Users\Praveen Bhargav\Desktop\INTERNSHIPS\PreSkale\Sentiment_Analysis\Twitter Analysis\EDA FOR REVIEWS DATASET/Cleaned_reviews.csv",index_col="Unnamed: 0")
df.head()
# Out:
#            userName                                            content  score  \
# 0     Andrew Thomas  Update: After getting a response from the deve...      1
# 1      Craig Haines  Used it for a fair amount of time without any ...      1
# 2     steven adkins  Your app sucks now!!!!! Used to be good but no...      1
# 3  Lars Panzerbjørn  It seems OK, but very basic. Recurring tasks n...      1
# 4     Scott Prewitt  Absolutely worthless. This app runs a prohibit...      1
#
#    Polarity                                         clean_text  \
# 0  Negative  update getting response developer would change...
# 1  Negative  used fair amount time without problem suddenly...
# 2  Negative  app suck used good doesnt update physically op...
# 3  Negative  seems ok basic recurring task need work actual...
# 4  Negative  absolutely worthless app run prohibitively clu...
#
#                                         common_words
# 0  ['update', 'getting', 'response', 'developer',...
# 1  ['used', 'fair', 'amount', 'time', 'without', ...
# 2  ['app', 'suck', 'used', 'good', 'doesnt', 'upd...
# 3  ['seems', 'ok', 'basic', 'recurring', 'task', ...
# 4  ['absolutely', 'worthless', 'app', 'run', 'pro...

# %%
df.columns
# Out:
# Index(['userName', 'content', 'score', 'Polarity', 'clean_text',
#        'common_words'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15746 entries, 0 to 15745
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   userName      15746 non-null  object
#  1   content       15746 non-null  object
#  2   score         15746 non-null  int64
#  3   Polarity      15746 non-null  object
#  4   clean_text    15737 non-null  object
#  5   common_words  15746 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 861.1+ KB

# %% [markdown]
# Some columns which i perceived are not useful for the modeling purpose and the target columns "Polarity" is essential to be encoded

# %%
df.drop(["score"],1,inplace=True)

# %%
df.columns
# Out:
# Index(['userName', 'content', 'Polarity', 'clean_text', 'common_words'], dtype='object')

# %%
df.Polarity.value_counts()
# Out:
# Positive    5676
# Neutral     5042
# Negative    5028
# Name: Polarity, dtype: int64

# %% [markdown]
# Label Encoding the Polarity

# %%
cond=[df.Polarity=="Positive",df.Polarity=="Neutral",df.Polarity=="Negative"]
choice=[2,1,0]
df.Polarity=np.select(cond,choice)
df.Polarity.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Polarity, dtype: int32

# %%
df.Polarity.value_counts() # checking with value_counts before label encoding
# Out:
# 2    5676
# 1    5042
# 0    5028
# Name: Polarity, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15746 entries, 0 to 15745
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   userName      15746 non-null  object
#  1   Polarity      15746 non-null  int32
#  2   clean_text    15737 non-null  object
#  3   common_words  15746 non-null  object
# dtypes: int32(1), object(3)
# memory usage: 553.6+ KB

# %%
df.isnull().sum()
# Out:
# userName        0
# Polarity        0
# clean_text      9
# common_words    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
X=df.clean_text
y=df.Polarity

# %%
# %%time
df.common_words
# Out:
# Wall time: 0 ns
# 0        ['update', 'getting', 'response', 'developer',...
# 1        ['used', 'fair', 'amount', 'time', 'without', ...
# 2        ['app', 'suck', 'used', 'good', 'doesnt', 'upd...
# 3        ['seems', 'ok', 'basic', 'recurring', 'task', ...
# 4        ['absolutely', 'worthless', 'app', 'run', 'pro...
#                                ...
# 15741    ['believe', 'far', 'best', 'app', 'helping', '...
# 15742                        ['sometimes', 'crash', 'lot']
# 15743                             ['work', 'well', 'need']
# 15744                                             ['love']
# 15745    ['really', 'amazing', 'helped', 'sooo', 'much'...
# Name: common_words, Length: 15737, dtype: object

# %%
# WORD2VEC 
W2V_SIZE = 300
W2V_WINDOW = 7
W2V_EPOCH = 32
W2V_MIN_COUNT = 10

# KERAS
embedding_dim = 300
vocab_size=1000
padding_type='post'
trunc_type='post'
oov_tok = "<OOV>"
max_length=150
EPOCHS= 20

# SENTIMENT
POSITIVE = "POSITIVE"
NEGATIVE = "NEGATIVE"
NEUTRAL = "NEUTRAL"
SENTIMENT_THRESHOLDS = (0.4, 0.7)

# # EXPORT
# KERAS_MODEL = "model.h5"
# WORD2VEC_MODEL = "model.w2v"
# TOKENIZER_MODEL = "tokenizer.pkl"
# ENCODER_MODEL = "encoder.pkl"

# %%
w2v_model = Word2Vec(size=W2V_SIZE,window=W2V_WINDOW,
                     min_count=W2V_MIN_COUNT,workers=8)

# %%
documents = [_text.split() for _text in df.clean_text] 
documents
# Out:
# [['update',
#   'getting',
#   'response',
#   'developer',
#   'would',
#   'change',
#   'rating',
#   'star',
#   'possible',
#   'guy',
#   'hide',
#   'behind',
#   'confusing',
#   'opaque',
#   'term',
#   'refuse',
#   'budge',
#   'im',
#   'annoyed',
#   'money',
#   'lost',
#   'really',
#   'terrible',
#   'customer',
#   'experience',
#   'original',
#   'careful',
#   'signing',
#   'free',
#   'trial',
#   'app',
#   'happen',
#   'go',
#   'automatically',
#   'charge',
#   'full',
#   'year',
#   'subscription',
#   'refuse',
#   'refund',
#   'terrible',
#   'customer',
#   'experience',
#   'app',
#   'ok'],
#  ['used',
#   'fair',
#   'amount',
#   'time',
#   'without',
#   'problem',
#   'suddenly',
#   'asked',
#   'create',
#   'account',
#   'log',
#   'using',
#   'google',
#   'fb',
#   'used',
#   'google',
#   'one',
#   'discover',
#   'everything',
#   'gone'],
#  ['app',
#   'suck',
#   'used',
#   'good',
#   'doesnt',
#   'update',
#   'physically',
#   'open',
#   'close',
#   'scroll',
#   'finally',
#   'show',
#   'want',
#   'put',
#   'list',
#   'friggen',
#   'paid',
#   'garbage'],
#  ['seems',
#   'ok',
#   'basic',
#   'recurring',
#   'task',
#   'need',
#   'work',
#   'actually',
#   'useful',
#   'example',
#   'would',
#   'nice',
#   'able',
#   'set',
#   'task',
#   'recurring',
#   'first',
#   'every',
#   'month',
#   'without',
#   'able',
#   'set',
#   'first',
#   'month',
#   'edit',
#   'also',
#   'noticed',
#   'dark',
#   'theme',
#   'may',
#   'available',
#   'paid',
#   'option',
#   'ill',
#   'never',
#   'know',
#   'since',
#   'basic',
#   'option',
#   'without',
#   'reason',
#   'try',
#   'app',
#   'thus',
#   'never',
#   'pay',
#   'actual',
#   'premium',
#   'option'],
#  ['absolutely',
#   'worthless',
#   'app',
#   'run',
#   'prohibitively',
#   'clunky',
#   'interface',
#   'effectively',
#   'void',
#   'promise',
#   'easeoflife',
#   'automation',
#   'google',
#   'calendar',
#   'provide',
#   'service',
#   'promised',
#   'free',
#   'annual',
#   'subscription',
#   'rate',
#   'dont',
#   'sign',
#   'free',
#   'trial',
#   'worth',
#   'getting',
#   'pinged',
#   'forty',
#   'buck',
#   'decide',
#   'dont',
#   'like',
#   'forget',
#   'cancel',
#   'time',
#   'save',
#   'money'],
#  ['beware',
#   'trial',
#   'period',
#   'scam',
#   'ive',
#   'using',
#   'free',
#   'version',
#   'decided',
#   'try',
#   'premium',
#   'day',
#   'per',
#   'trial',
#   'ad',
#   'day',
#   'realized',
#   'didnt',
#   'quite',
#   'organize',
#   'information',
#   'best',
#   'work',
#   'wrote',
#   'cancel',
#   'informed',
#   'must',
#   'accidentally',
#   'signed',
#   'non',
#   'trial',
#   'strict',
#   'term',
#   'cannot',
#   'refund',
#   'wrote',
#   'back',
#   'nicely',
#   'intention',
#   'try',
#   'per',
#   'ad',
#   'said',
#   'possible',
#   'really'],
#  ['dont',
#   'buy',
#   'premium',
#   'pay',
#   'entire',
#   'year',
#   'upfront',
#   'change',
#   'mind',
#   'app',
#   'like',
#   'due',
#   'odd',
#   'inconsistent',
#   'behavior',
#   'reaccuring',
#   'task',
#   'reminder',
#   'youre',
#   'given',
#   'hour',
#   'day',
#   'trial',
#   'qualify',
#   'refund',
#   'youre',
#   'screwed',
#   'issue',
#   'started',
#   'happening',
#   'period',
#   'ended',
#   'obviously',
#   'know',
#   'problem',
#   'app',
#   'read',
#   'robotic',
#   'response',
#   'issue',
#   'anydo',
#   'hide',
#   'behind',
#   'tos',
#   'instead',
#   'helping'],
#  ['could',
#   'awesome',
#   'app',
#   'great',
#   'potential',
#   'except',
#   'flaw',
#   'end',
#   'making',
#   'super',
#   'irritating',
#   'app',
#   'reported',
#   'issue',
#   'apps',
#   'tech',
#   'support',
#   'several',
#   'time',
#   'get',
#   'lame',
#   'response',
#   'resolution',
#   'latest',
#   'item',
#   'entered',
#   'category',
#   'app',
#   'app',
#   'reason',
#   'resort',
#   'sequence',
#   'item',
#   'list',
#   'automatically',
#   'put',
#   'item',
#   'list',
#   'certain',
#   'order',
#   'reason',
#   'issue',
#   'moreroomher'],
#  ['app',
#   'felt',
#   'good',
#   'enough',
#   'buy',
#   'yearly',
#   'subscription',
#   'paid',
#   'th',
#   '€',
#   'requested',
#   'week',
#   'later',
#   'charged',
#   'euro',
#   'credit',
#   'card',
#   'subscription',
#   'feature',
#   'basically',
#   'paid',
#   '€',
#   'scam',
#   'unless',
#   'get',
#   '€',
#   'euro',
#   'back',
#   'im',
#   'gonna',
#   'keep',
#   'rating',
#   'one',
#   'star'],
#  ['downloaded',
#   'login',
#   'google',
#   'never',
#   'anything',
#   'logged',
#   'google',
#   'asking',
#   'many',
#   'time',
#   'auto',
#   'debit',
#   'subscription',
#   'uninstalled',
#   'still',
#   'min',
#   'r',
#   'debited',
#   'account',
#   'muging',
#   'money',
#   'want',
#   'refund',
#   'money',
#   'account',
#   'kindly'],
#  ['app',
#   'useless',
#   'work',
#   'notepad',
#   'task',
#   'notify',
#   'task',
#   'suppose',
#   'time',
#   'reach',
#   'silent',
#   'doesnt',
#   'pop',
#   'even',
#   'though',
#   'setting',
#   'permitted',
#   'pop',
#   'alert',
#   'even',
#   'simple',
#   'alarm',
#   'clock',
#   'notified',
#   'app',
#   'doesnt',
#   'work'],
#  ['really',
#   'disappointed',
#   'find',
#   'recurring',
#   'task',
#   'functionality',
#   'available',
#   'paid',
#   'version',
#   'would',
#   'recommend',
#   'also',
#   'doesnt',
#   'sort',
#   'task',
#   'date',
#   'time',
#   'properly'],
#  ['loaded',
#   'trial',
#   'emailed',
#   'cancelation',
#   'email',
#   'bounced',
#   'back',
#   'ended',
#   'paying',
#   'app',
#   'didnt',
#   'want',
#   'way',
#   'contact',
#   'refund',
#   'careful',
#   'buy',
#   'try',
#   'trial',
#   'youre',
#   'stuck',
#   'paying'],
#  ['cant',
#   'reedit',
#   'time',
#   'ive',
#   'set',
#   'necessary',
#   'delete',
#   'redo',
#   'process',
#   'also',
#   'need',
#   'reminder',
#   'every',
#   'hour',
#   'create',
#   'reminder',
#   'instead',
#   'reminder',
#   'running',
#   'every',
#   'hour',
#   'poorly',
#   'designed'],
#  ['thanks',
#   'developer',
#   'quick',
#   'response',
#   'however',
#   'calendar',
#   'useless',
#   'group',
#   'without',
#   'featureswe',
#   'decided',
#   'go',
#   'business',
#   'calendar',
#   'pro',
#   'previous',
#   'comment',
#   'wasnt',
#   'able',
#   'see',
#   'month',
#   'year',
#   'view'],
#  ['originally',
#   'star',
#   'app',
#   'use',
#   'allowing',
#   'access',
#   'either',
#   'email',
#   'facebook',
#   '😡',
#   '😡',
#   '😡',
#   'definitely',
#   'happy',
#   'allow',
#   'deleted',
#   'app',
#   'would',
#   'give',
#   'zero',
#   'star',
#   'could'],
#  ['couldnt',
#   'even',
#   'set',
#   'one',
#   'single',
#   'recurring',
#   'reminder',
#   'without',
#   'required',
#   'pay',
#   'monthly',
#   'subscription',
#   'get',
#   'greedy',
#   'hand',
#   'dev',
#   'reminder',
#   'app',
#   'useful',
#   'service'],
#  ['hey',
#   'something',
#   'wrong',
#   'billing',
#   'signed',
#   'accountthat',
#   'tuition',
#   'upkeep',
#   'feei',
#   'berely',
#   'even',
#   'use',
#   'app',
#   'even',
#   'please',
#   'need',
#   'back',
#   'refundthis',
#   'isnt',
#   'righti',
#   'would',
#   'file',
#   'report',
#   'google',
#   'play',
#   'storethis',
#   'totally',
#   'scammy',
#   'please',
#   'guy',
#   'totally',
#   'avoid',
#   'app',
#   'please',
#   'jesus',
#   'christ',
#   'totally',
#   'expected',
#   'billed',
#   'sudden',
#   'totally',
#   'far',
#   'frm',
#   'fair',
#   'please'],
#  ['reported',
#   'app',
#   'due',
#   'incorrect',
#   'billing',
#   'noone',
#   'answer',
#   'please',
#   'return',
#   'money',
#   'back',
#   'app',
#   'took',
#   'money',
#   'without',
#   'permission',
#   'credit',
#   'card'],
#  ['fact',
#   'pay',
#   'much',
#   'use',
#   'something',
#   'simple',
#   'isnt',
#   'worth',
#   'free',
#   'apps',
#   'similar',
#   'functionality'],
#  ['need',
#   'premium',
#   'level',
#   'import',
#   'wunderlist',
#   'b',
#   'reset',
#   'password',
#   'everytime',
#   'login',
#   'havent',
#   'able',
#   'even',
#   'try',
#   'app'],
#  ['cant',
#   'use',
#   'without',
#   'registering',
#   'email',
#   'address',
#   'immediate',
#   'uninstall'],
#  ['complicated', 'dislike', 'pro', 'version', 'microft', 'list', 'better'],
#  ['close', 'list', 'feature', 'available', 'bin', 'premium', 'mode'],
#  ['slow',
#   'flow',
#   'turned',
#   'click',
#   'via',
#   'home',
#   'page',
#   'widget',
#   'fade',
#   'effect',
#   'lagging',
#   'please',
#   'kindly',
#   'help',
#   'check',
#   'thank'],
#  ['looked',
#   'appears',
#   'apps',
#   'signed',
#   'subscription',
#   'trying',
#   'find',
#   'subscriped',
#   'want',
#   'app'],
#  ['app',
#   'would',
#   'let',
#   'start',
#   'new',
#   'day',
#   'listed',
#   'task',
#   'performed',
#   'one',
#   'day',
#   'overdue',
#   'next',
#   'day',
#   'weird'],
#  ['month',
#   'view',
#   'hard',
#   'find',
#   'decent',
#   'calendar',
#   'whole',
#   'month',
#   'view'],
#  ['basic',
#   'app',
#   'without',
#   'exciting',
#   'feature',
#   'pay',
#   'useless',
#   'app',
#   'please',
#   'dont',
#   'download',
#   'cheat',
#   'waste',
#   'time',
#   'energy'],
#  ['would',
#   'nice',
#   'know',
#   'price',
#   'using',
#   'data',
#   'download',
#   'uninstalled',
#   'second',
#   'later'],
#  ['absolute',
#   'rubbish',
#   'killing',
#   'wunderlist',
#   'clear',
#   'example',
#   'domanant',
#   'power',
#   'big',
#   'thug',
#   'microsoft',
#   'google',
#   'amazon',
#   'etc',
#   'taking',
#   'better',
#   'competitor',
#   'push',
#   'inferior',
#   'garbage',
#   'trying',
#   'ticktock'],
#  ['deducted',
#   'money',
#   'reason',
#   'used',
#   'service',
#   'never',
#   'used',
#   'return',
#   'money',
#   'immediately'],
#  ['keep',
#   'failing',
#   'repeat',
#   'daily',
#   'task',
#   'ive',
#   'remake',
#   'task',
#   'several',
#   'time',
#   'wont',
#   'stick',
#   'reason',
#   'sometimes',
#   'work',
#   'sometimes',
#   'doesnt',
#   'complete',
#   'gamble',
#   'work',
#   'figure',
#   'task',
#   'need',
#   'done',
#   'task',
#   'uninstalling',
#   'app',
#   'maintenance',
#   'daily',
#   'chore'],
#  ['copied',
#   'google',
#   'calendar',
#   'charging',
#   'top',
#   'google',
#   'calendar',
#   'far',
#   'better'],
#  ['premium', 'support', 'contacted', 'day', 'counting'],
#  ['want', 'calendar', 'app', 'spam', 'much', 'star'],
#  ['free',
#   'version',
#   'limited',
#   'thousand',
#   'similar',
#   'free',
#   'apps',
#   'paid',
#   'one',
#   'dev',
#   'like',
#   'argue',
#   'app',
#   'really',
#   'useful',
#   'unless',
#   'buy',
#   'monthly',
#   'subscription',
#   'changed',
#   'star',
#   'developer',
#   'actively',
#   'misleading'],
#  ['free', 'billed', 'without', 'knowing', 'loss', 'money'],
#  ['worst',
#   'app',
#   'premium',
#   'yearly',
#   'pay',
#   'r',
#   'option',
#   'monthly',
#   'payment',
#   'bad',
#   'app'],
#  ['looked',
#   'good',
#   'doesnt',
#   'work',
#   'scheduled',
#   'simple',
#   'task',
#   'would',
#   'change',
#   'timing',
#   'corrected',
#   'make',
#   'right',
#   'several',
#   'time',
#   'navigation',
#   'difficult',
#   'like',
#   'id',
#   'want',
#   'set',
#   'task',
#   'id',
#   'say',
#   'task',
#   'complete',
#   'wouldnt',
#   'sure',
#   'saved',
#   'couldnt',
#   'back',
#   'see',
#   'task',
#   'set',
#   'correctly',
#   'confirm',
#   'task',
#   'done',
#   'undo',
#   'task',
#   'later',
#   'might',
#   'change',
#   'time',
#   'something',
#   'never',
#   'set',
#   '😳'],
#  ['used',
#   'app',
#   'month',
#   'daily',
#   'basis',
#   'finding',
#   'really',
#   'useful',
#   'however',
#   'app',
#   'recently',
#   'forced',
#   'update',
#   'task',
#   'deleted',
#   'result',
#   'specific',
#   'category',
#   'set',
#   'tried',
#   'deleting',
#   'app',
#   'fully',
#   'redownloading',
#   'see',
#   'helped',
#   'task',
#   'still',
#   'didnt',
#   'reappear',
#   'even',
#   'though',
#   'diary',
#   'syncing',
#   'ok',
#   'lost',
#   'task',
#   'cant',
#   'remember',
#   'info',
#   'included',
#   'task',
#   'shaken',
#   'faith',
#   'using',
#   'app',
#   'particularly',
#   'havent',
#   'received',
#   'response',
#   'message',
#   'sent',
#   'team',
#   'via',
#   'support',
#   'link',
#   'several',
#   'day',
#   'ago'],
#  ['really',
#   'wanted',
#   'love',
#   'app',
#   'exactly',
#   'need',
#   'unfortunately',
#   'riddled',
#   'bug',
#   'mostly',
#   'repeat',
#   'task',
#   'main',
#   'one',
#   'phone',
#   'powered',
#   'reminder',
#   'time',
#   'break',
#   'reminder',
#   'resetting',
#   'task',
#   'brings',
#   'issue',
#   'also',
#   'take',
#   'app',
#   'sync',
#   'widget',
#   'contacted',
#   'priority',
#   'support',
#   'one',
#   'reply',
#   'day',
#   'seems',
#   'real',
#   'interest',
#   'fixing',
#   'problem',
#   'blamed',
#   'nova',
#   'launcher',
#   'thing',
#   'happens',
#   'samsung',
#   'launcher'],
#  ['custom', 'notification', 'sound', 'really'],
#  ['used',
#   'goto',
#   'shopping',
#   'list',
#   'update',
#   'later',
#   'become',
#   'frustrating',
#   'wasteful',
#   'im',
#   'going',
#   'saved',
#   'item',
#   'category',
#   'add',
#   'back',
#   'list',
#   'category',
#   'randomly',
#   'close',
#   'reopen',
#   'could',
#   'run',
#   'list',
#   'click',
#   'needed',
#   'add'],
#  ['nothing',
#   'problem',
#   'app',
#   'first',
#   'smart',
#   'list',
#   'didnt',
#   'work',
#   'magically',
#   'started',
#   'working',
#   'next',
#   'morning',
#   'thought',
#   'everything',
#   'great',
#   'alexa',
#   'sync',
#   'stopped',
#   'working',
#   'working',
#   'stopped',
#   'would',
#   'sync',
#   'alexa',
#   'added',
#   'anydo',
#   'added',
#   'alexa',
#   'voice',
#   'effort',
#   'fix',
#   'disabled',
#   'skill',
#   'cant',
#   'get',
#   'reenable',
#   'mess'],
#  ['subscription',
#   'app',
#   'simple',
#   'insane',
#   'one',
#   'time',
#   'payment',
#   'around',
#   'advice',
#   'wont',
#   'last',
#   'long',
#   'kind',
#   'strategy'],
#  ['app', 'ignores', 'phone', 'dark', 'mode', 'unless', 'pay', 'garbage'],
#  ['app',
#   'seems',
#   'useful',
#   'regretfully',
#   'going',
#   'uninstall',
#   'pushy',
#   'keep',
#   'reminding',
#   'use',
#   'issue',
#   'app',
#   'day',
#   'ago',
#   'found',
#   'put',
#   'lock',
#   'screen',
#   'put',
#   'specifically',
#   'put',
#   'transit',
#   'app',
#   'lock',
#   'screen',
#   'changed',
#   'back',
#   'thinking',
#   'uninstalling',
#   'happens',
#   'happened',
#   'morning',
#   'noticed',
#   'changed',
#   'back',
#   'anydo',
#   'place',
#   'want',
#   'transit',
#   'app',
#   'goodbye',
#   'anydo'],
#  ['like',
#   'developer',
#   'claim',
#   'apps',
#   'free',
#   'wait',
#   'free',
#   'mean',
#   'free',
#   'even',
#   'data',
#   'cost',
#   'money',
#   'stop',
#   'pretending',
#   'crappy',
#   'apps',
#   'free',
#   'note',
#   'app',
#   'one',
#   'nothing',
#   'invasive'],
#  ['get',
#   'want',
#   'upgrade',
#   'even',
#   'tried',
#   'app',
#   'shove',
#   'face',
#   'dont',
#   'like',
#   'promoting',
#   'pro',
#   'version',
#   'delete',
#   'account',
#   'want',
#   'password',
#   'gmail',
#   'account',
#   'privacy',
#   'breach',
#   'also',
#   'many',
#   'thing',
#   'wrong',
#   'app',
#   'ethos',
#   'none',
#   'integration',
#   'work',
#   'unless',
#   'pay',
#   'totally',
#   'money',
#   'grab',
#   'guy',
#   'ive',
#   'read',
#   'elsewhere',
#   'ive',
#   'deleted',
#   'made',
#   'feel',
#   'intrusive'],
#  ['used',
#   'app',
#   'previous',
#   'android',
#   'offer',
#   'awesome',
#   'feature',
#   'however',
#   'working',
#   'installing',
#   'new',
#   'android',
#   'redmi',
#   'note',
#   'used',
#   'app',
#   'want',
#   'working',
#   'cost',
#   'pls',
#   'help',
#   'resolve',
#   'app',
#   'launch',
#   'next',
#   'morning',
#   'add',
#   'task',
#   'doesnt',
#   'launch'],
#  ['require',
#   'sign',
#   'edit',
#   'response',
#   'reply',
#   'ridiculous',
#   'couldnt',
#   'even',
#   'try',
#   'app',
#   'providing',
#   'detail',
#   'ive',
#   'found',
#   'wonderful',
#   'app',
#   'allows',
#   'skip',
#   'sign',
#   'unless',
#   'wish',
#   'sync',
#   'etc',
#   'ill',
#   'sticking',
#   'app',
#   'perfect',
#   'need',
#   'provide',
#   'info',
#   'wish'],
#  ['couldnt',
#   'find',
#   'google',
#   'assistant',
#   'integration',
#   'anywhere',
#   'even',
#   'though',
#   'advertised',
#   'everywhere',
#   'searching',
#   'web',
#   'app',
#   'edit',
#   'even',
#   'description',
#   'app',
#   'thats',
#   'false',
#   'advertising',
#   'edit',
#   'review',
#   'beta',
#   'working',
#   'final',
#   'version'],
#  ['horribly',
#   'simplistic',
#   'found',
#   'paid',
#   'premium',
#   'way',
#   'change',
#   'due',
#   'date',
#   'existing',
#   'task',
#   'render',
#   'program',
#   'useless',
#   'lack',
#   'core',
#   'functionalitiesbut',
#   'would',
#   'never',
#   'ever',
#   'conceived',
#   'due',
#   'date',
#   'existing',
#   'task',
#   'cannot',
#   'changed',
#   'ripped'],
#  ['waste', 'time', 'failed', 'pair', 'mu', 'gmail', 'accountgave', 'attempt'],
#  ['upgraded', 'lost', 'task', 'previous', 'version', 'disappointed'],
#  ['app',
#   'requires',
#   'user',
#   'create',
#   'account',
#   'either',
#   'fb',
#   'gmail',
#   'use',
#   'find',
#   'day',
#   'free',
#   'trial',
#   'order',
#   'pay',
#   'later',
#   'encouraging',
#   'even',
#   'try',
#   'least',
#   'inform',
#   'user',
#   'thats',
#   'free',
#   'asking',
#   'access',
#   'fb',
#   'gmail',
#   'account'],
#  ['download',
#   'app',
#   'unsubscribed',
#   'premium',
#   'could',
#   'charge',
#   'decided',
#   'couldnt',
#   'afford',
#   'im',
#   'broke',
#   'college',
#   'student',
#   'took',
#   'money',
#   'anyway',
#   'tried',
#   'contact',
#   'dont',
#   'number',
#   'call',
#   'emailed',
#   'told',
#   'didnt',
#   'charge',
#   'asked',
#   'give',
#   'contact',
#   'info',
#   'financer',
#   'could',
#   'send',
#   'bank',
#   'statement',
#   'ignored',
#   'email',
#   'stole',
#   'money',
#   'dont',
#   'use',
#   'app',
#   'worth'],
#  ['download',
#   'app',
#   'want',
#   'keep',
#   'money',
#   'account',
#   'took',
#   'unauthorized',
#   'almost',
#   'account',
#   'help',
#   'page',
#   'say',
#   'offer',
#   'refund',
#   'within',
#   'hour',
#   'however',
#   'offer',
#   'access',
#   'claim',
#   'refund'],
#  ['wont',
#   'stop',
#   'charging',
#   'cancellation',
#   'happened',
#   'year',
#   'promised',
#   'one',
#   'year',
#   'ago',
#   'would',
#   'stop',
#   'actually',
#   'cancel',
#   'credit',
#   'card',
#   'upon',
#   'reading',
#   'review',
#   'find',
#   'one',
#   'excessive',
#   'billing',
#   'issue'],
#  ['free',
#   'want',
#   'pay',
#   'using',
#   'social',
#   'medium',
#   'required',
#   'want',
#   'register',
#   'using',
#   'popular',
#   'company',
#   'popular',
#   'enough',
#   'remove',
#   'last',
#   'star',
#   'review',
#   'send',
#   'email',
#   'disputing',
#   'plenty',
#   'better',
#   'note',
#   'taking',
#   'apps',
#   'exist',
#   'highly',
#   'advise',
#   'invasive',
#   'app'],
#  ['user',
#   'friendly',
#   'directly',
#   'asking',
#   'moneyi',
#   'already',
#   'uninstalled'],
#  ['keep',
#   'notify',
#   'sound',
#   'without',
#   'notification',
#   'task',
#   'every',
#   'time',
#   'open',
#   'app',
#   'got',
#   'pop',
#   'window',
#   'old',
#   'task',
#   'finished',
#   'already',
#   'along',
#   'time',
#   'ago',
#   'matter',
#   'good',
#   'app'],
#  ['tech',
#   'support',
#   'vague',
#   'pricing',
#   'im',
#   'sorry',
#   'lost',
#   'interested',
#   'customer',
#   'cancelled',
#   'trial',
#   'plan',
#   'subscribing',
#   'premium'],
#  ['bad',
#   'experience',
#   'subscription',
#   'refuse',
#   'give',
#   'back',
#   'month',
#   'havent',
#   'used',
#   'canceling',
#   'want',
#   'yearly',
#   'subscription',
#   'mac',
#   'app',
#   'crash',
#   'get',
#   'stuck'],
#  ['wow',
#   'completely',
#   'annoying',
#   'trying',
#   'get',
#   'buy',
#   'premium',
#   'ever',
#   'page',
#   'much',
#   'trying'],
#  ['installed',
#   'started',
#   'setup',
#   'everything',
#   'installed',
#   'requred',
#   'subscription',
#   'install',
#   'want',
#   'pay',
#   'everything',
#   'probably',
#   'stated',
#   'good',
#   'point',
#   'app',
#   'require',
#   'subscription',
#   'uninstalling',
#   'app'],
#  ['used',
#   'like',
#   'shopping',
#   'basket',
#   'missing',
#   'cant',
#   'make',
#   'grocery',
#   'list',
#   'anymore',
#   'annoying'],
#  ['shity',
#   'app',
#   'top',
#   'subscribed',
#   'monthly',
#   'charge',
#   'year',
#   'cancel',
#   'subscription',
#   'return',
#   'policy',
#   'google',
#   'reminder',
#   'app',
#   'million',
#   'time',
#   'better'],
#  ['hate',
#   'apps',
#   'try',
#   'trick',
#   'subscribing',
#   'transparent',
#   'condition',
#   'use',
#   'alone',
#   'uninstalled',
#   'app',
#   'straight',
#   'away'],
#  ['deceptive',
#   'billing',
#   'practice',
#   'information',
#   'cancelling',
#   'circular',
#   'emailed',
#   'link',
#   'advises',
#   'email',
#   'doesnt',
#   'colour',
#   'tag',
#   'functionality',
#   'across',
#   'web',
#   'app',
#   'poor',
#   'ux',
#   'worse',
#   'customer',
#   'service'],
#  ['canceled',
#   'subscription',
#   'first',
#   'time',
#   'used',
#   'anydo',
#   'still',
#   'pay',
#   'try',
#   'free',
#   'trial',
#   'first',
#   'using',
#   'app'],
#  ['replying',
#   'free',
#   'app',
#   'every',
#   'option',
#   'show',
#   'get',
#   'access',
#   'tool',
#   'purchasing'],
#  ['app',
#   'used',
#   'good',
#   'recurring',
#   'reminder',
#   'time',
#   'change',
#   'everyday',
#   'time',
#   'completed',
#   'task'],
#  ['unusable',
#   'without',
#   'account',
#   'even',
#   'im',
#   'interested',
#   'cloud',
#   'feature'],
#  ['ive',
#   'feel',
#   'deceived',
#   'app',
#   'there',
#   'assistant',
#   'whatsapp',
#   'integration',
#   'doesnt',
#   'work',
#   'also',
#   'contacted',
#   'support',
#   'got',
#   'answer',
#   'im',
#   'cancelling',
#   'subscription'],
#  ['premium',
#   'version',
#   'advertised',
#   'per',
#   'year',
#   'tap',
#   'change',
#   'odd',
#   'whats'],
#  ['downloaded',
#   'appuninstalled',
#   'within',
#   'day',
#   'offer',
#   'free',
#   'noticed',
#   'charged',
#   'full',
#   'year',
#   'subscription',
#   'inr',
#   'sneaky',
#   'way',
#   'generate',
#   'revenue'],
#  ['never',
#   'knew',
#   'could',
#   'callender',
#   'planner',
#   'bug',
#   'mutch',
#   'definitely',
#   'remind',
#   'thing',
#   'stop',
#   'interested'],
#  ['bad',
#   'app',
#   'able',
#   'close',
#   'account',
#   'forcefully',
#   'charging',
#   'amount'],
#  ['im',
#   'using',
#   'one',
#   'plus',
#   'android',
#   'alarm',
#   'reminder',
#   'doesnt',
#   'work'],
#  ['disappointing',
#   'complete',
#   'waste',
#   'money',
#   'add',
#   'note',
#   'daily',
#   'repeating',
#   'calendar',
#   'event',
#   'free',
#   'easy'],
#  ['purchsed',
#   'one',
#   'month',
#   'try',
#   'integrate',
#   'whatsapp',
#   'working',
#   'even',
#   'able',
#   'click',
#   'resend',
#   'otp'],
#  ['cannot',
#   'link',
#   'google',
#   'product',
#   'keep',
#   'note',
#   'tag',
#   'function',
#   'force',
#   'user',
#   'upgrade'],
#  ['ensure',
#   'read',
#   'comment',
#   'payment',
#   'every',
#   'critical',
#   'comment',
#   'true',
#   'app',
#   'isnt',
#   'worth',
#   'youre',
#   'charged',
#   'recommend',
#   'beware'],
#  ['font', 'small', 'read', 'way', 'change'],
#  ['able', 'set', 'reminder', 'default', 'pm', 'able', 'select'],
#  ['day',
#   'trail',
#   'fill',
#   'card',
#   'detail',
#   'take',
#   'subscription',
#   'worst',
#   'trick'],
#  ['hi',
#   'app',
#   'state',
#   'free',
#   'yet',
#   'charge',
#   'day',
#   'dont',
#   'mislead',
#   'people'],
#  ['pay', 'amount', 'list', 'app', 'im', 'uninstalling', 'min', 'installation'],
#  ['work', 'without', 'connecting', 'account'],
#  ['hope',
#   'calendar',
#   'inside',
#   'keep',
#   'completed',
#   'todo',
#   'list',
#   'history'],
#  ['immediately',
#   'want',
#   'buy',
#   'full',
#   'version',
#   'app',
#   'demo',
#   'part',
#   'even',
#   'nice'],
#  ['multiprotocol',
#   'task',
#   'manager',
#   'description',
#   'false',
#   'implies',
#   'front',
#   'end',
#   'service',
#   'couldnt',
#   'get',
#   'past',
#   'first',
#   'screen',
#   'requires',
#   'set',
#   'account',
#   'sync',
#   'use',
#   'private',
#   'server',
#   'capable',
#   'syncing',
#   'thing',
#   'like',
#   'task',
#   'exchange',
#   'public',
#   'cloud',
#   'google',
#   'icloud',
#   'email',
#   'provider',
#   'capability',
#   'therefore',
#   'need',
#   'send',
#   'data',
#   'elsewhere',
#   'already',
#   'server',
#   'fact',
#   'data',
#   'something',
#   'touch',
#   'doesnt',
#   'make',
#   'le',
#   'valuable',
#   'mindful',
#   'valuable',
#   'asset',
#   'today',
#   'may',
#   'tangible',
#   'sure',
#   'quantified',
#   'endlessly',
#   'requiring',
#   'signing',
#   'app',
#   'huge',
#   'red',
#   'flag'],
#  ['premium',
#   'scamthe',
#   'app',
#   'pushy',
#   'annoying',
#   'couldnt',
#   'get',
#   'incoming',
#   'call',
#   'blocked',
#   'screen',
#   'call',
#   'doesnt',
#   'appear',
#   'screen',
#   'hear',
#   'hopelessly',
#   'looking',
#   'call',
#   'screen',
#   'get',
#   'call',
#   'dropped',
#   'call',
#   'back',
#   'disturbing',
#   'annoying',
#   'barely',
#   'used',
#   'app',
#   'maintain',
#   'take',
#   'lot',
#   'time',
#   'asked',
#   'cancel',
#   'said',
#   'refund',
#   'passed',
#   'yearly',
#   'subscription'],
#  ['doesnt',
#   'offer',
#   'anything',
#   'cant',
#   'google',
#   'calendar',
#   'least',
#   'free',
#   'version',
#   'im',
#   'going',
#   'pay',
#   'app',
#   'basically',
#   'going',
#   'import',
#   'google',
#   'calendar',
#   'thing',
#   'google',
#   'free',
#   'also',
#   'saw',
#   'another',
#   'review',
#   'deleted',
#   'review',
#   'shady',
#   'get',
#   'deleted',
#   'ill',
#   'look',
#   'legal',
#   'law',
#   'governing',
#   'false',
#   'advertising'],
#  ['cant',
#   'change',
#   'default',
#   'theme',
#   'black',
#   'asks',
#   'change',
#   'plan',
#   'free',
#   'premium'],
#  ['unable', 'subscribe', 'app', 'payment', 'method', 'declined'],
#  ['there',
#   'always',
#   'something',
#   'shifty',
#   'app',
#   'shouldnt',
#   'need',
#   'subscription',
#   'absolute',
#   'minimum',
#   'make',
#   'setting',
#   'reminder',
#   'complicated',
#   'theyre',
#   'hoping',
#   'forget',
#   'end',
#   'free',
#   'trial',
#   'start',
#   'automatic',
#   'payment',
#   'thats',
#   'apps',
#   'work',
#   'youre',
#   'better',
#   'setting',
#   'alarm',
#   'phone',
#   'clock',
#   'repeat',
#   'using'],
#  ['manage', 'subscription', 'given', 'app', 'menu'],
#  ['disappointed',
#   'cant',
#   'plan',
#   'task',
#   'multiple',
#   'day',
#   'manually',
#   'adding',
#   'task',
#   'repeat',
#   'day',
#   'downside',
#   'uninstalled'],
#  ['ok'],
#  ['update',
#   'getting',
#   'response',
#   'developer',
#   'would',
#   'change',
#   'rating',
#   'star',
#   'possible',
#   'guy',
#   'hide',
#   'behind',
#   'confusing',
#   'opaque',
#   'term',
#   'refuse',
#   'budge',
#   'im',
#   'annoyed',
#   'money',
#   'lost',
#   'really',
#   'terrible',
#   'customer',
#   'experience',
#   'original',
#   'careful',
#   'signing',
#   'free',
#   'trial',
#   'app',
#   'happen',
#   'go',
#   'automatically',
#   'charge',
#   'full',
#   'year',
#   'subscription',
#   'refuse',
#   'refund',
#   'terrible',
#   'customer',
#   'experience',
#   'app',
#   'ok'],
#  ['cant',
#   'get',
#   'finish',
#   'installing',
#   'plenty',
#   'room',
#   'get',
#   'stop',
#   'revise',
#   'review',
#   'ever',
#   'get',
#   'try'],
#  ['stop',
#   'charging',
#   'people',
#   'thing',
#   'simple',
#   'use',
#   'onenote',
#   'buy',
#   'great',
#   'planner',
#   'amazon',
#   'copy',
#   'template',
#   'save',
#   'money'],
#  ['used',
#   'fair',
#   'amount',
#   'time',
#   'without',
#   'problem',
#   'suddenly',
#   'asked',
#   'create',
#   'account',
#   'log',
#   'using',
#   'google',
#   'fb',
#   'used',
#   'google',
#   'one',
#   'discover',
#   'everything',
#   'gone'],
#  ['pay'],
#  ['useless', 'keep', 'erasing', 'everything', 'dominate', 'app', 'easy'],
#  ['app', 'bur', 'futti', 'randi', 'chodari'],
#  ['custom', 'notification', 'sound', 'really'],
#  ['app',
#   'suck',
#   'used',
#   'good',
#   'doesnt',
#   'update',
#   'physically',
#   'open',
#   'close',
#   'scroll',
#   'finally',
#   'show',
#   'want',
#   'put',
#   'list',
#   'friggen',
#   'paid',
#   'garbage'],
#  ['delete'],
#  ['per', 'month', 'make', 'app', 'usable', 'po'],
#  ['worth'],
#  ['downloaded',
#   'login',
#   'google',
#   'never',
#   'anything',
#   'logged',
#   'google',
#   'asking',
#   'many',
#   'time',
#   'auto',
#   'debit',
#   'subscription',
#   'uninstalled',
#   'still',
#   'min',
#   'r',
#   'debited',
#   'account',
#   'muging',
#   'money',
#   'want',
#   'refund',
#   'money',
#   'account',
#   'kindly'],
#  ['day', 'trial', 'sufficient', 'month', 'would', 'better'],
#  ['app', 'super', 'best'],
#  ['pay', 'app', 'havent', 'installed', 'huh', '😠', '😠', '😠'],
#  ['cannot',
#   'change',
#   'theme',
#   'anymore',
#   'missing',
#   'notification',
#   'liked',
#   'previously'],
#  ['isnt', 'basically', 'calendar', 'phone'],
#  ['reminder', 'doesnt', 'work'],
#  ['recurrent',
#   'task',
#   'skip',
#   'marking',
#   'one',
#   'done',
#   'doesnt',
#   'remind',
#   'next',
#   'time',
#   'say',
#   'week',
#   'next',
#   'day',
#   'repetition',
#   'set',
#   'daily'],
#  ['doesnt', 'sync'],
#  ['canceled',
#   'subscription',
#   'first',
#   'time',
#   'used',
#   'anydo',
#   'still',
#   'pay',
#   'try',
#   'free',
#   'trial',
#   'first',
#   'using',
#   'app'],
#  ['help',
#   'tutorial',
#   'available',
#   'day',
#   'could',
#   'even',
#   'find',
#   'delete',
#   'note',
#   'perhaps',
#   'stupid',
#   'perhaps',
#   'doesnt',
#   'work',
#   'phone',
#   'uninstalled',
#   'well',
#   'try',
#   'something',
#   'else',
#   'work',
#   'google',
#   'assistant'],
#  ['really',
#   'disappointed',
#   'find',
#   'recurring',
#   'task',
#   'functionality',
#   'available',
#   'paid',
#   'version',
#   'would',
#   'recommend',
#   'also',
#   'doesnt',
#   'sort',
#   'task',
#   'date',
#   'time',
#   'properly'],
#  ['beware',
#   'trial',
#   'period',
#   'scam',
#   'ive',
#   'using',
#   'free',
#   'version',
#   'decided',
#   'try',
#   'premium',
#   'day',
#   'per',
#   'trial',
#   'ad',
#   'day',
#   'realized',
#   'didnt',
#   'quite',
#   'organize',
#   'information',
#   'best',
#   'work',
#   'wrote',
#   'cancel',
#   'informed',
#   'must',
#   'accidentally',
#   'signed',
#   'non',
#   'trial',
#   'strict',
#   'term',
#   'cannot',
#   'refund',
#   'wrote',
#   'back',
#   'nicely',
#   'intention',
#   'try',
#   'per',
#   'ad',
#   'said',
#   'possible',
#   'really'],
#  ['want', 'calendar', 'app', 'spam', 'much', 'star'],
#  ['requires', 'registration'],
#  ['please', 'free', 'colour', 'theme', 'tag', 'give', 'star'],
#  ['app', 'kept', 'losing', 'reminder'],
#  ['work'],
#  ['basic',
#   'app',
#   'without',
#   'exciting',
#   'feature',
#   'pay',
#   'useless',
#   'app',
#   'please',
#   'dont',
#   'download',
#   'cheat',
#   'waste',
#   'time',
#   'energy'],
#  ['much', 'cost'],
#  ['user',
#   'friendly',
#   'directly',
#   'asking',
#   'moneyi',
#   'already',
#   'uninstalled'],
#  ['trashy', 'app', 'total', 'waste', 'time', '🤞', '🏽'],
#  ['app',
#   'felt',
#   'good',
#   'enough',
#   'buy',
#   'yearly',
#   'subscription',
#   'paid',
#   'th',
#   '€',
#   'requested',
#   'week',
#   'later',
#   'charged',
#   'euro',
#   'credit',
#   'card',
#   'subscription',
#   'feature',
#   'basically',
#   'paid',
#   '€',
#   'scam',
#   'unless',
#   'get',
#   '€',
#   'euro',
#   'back',
#   'im',
#   'gonna',
#   'keep',
#   'rating',
#   'one',
#   'star'],
#  ['pay', 'dark', 'mode', 'lol'],
#  ['absolutely',
#   'worthless',
#   'app',
#   'run',
#   'prohibitively',
#   'clunky',
#   'interface',
#   'effectively',
#   'void',
#   'promise',
#   'easeoflife',
#   'automation',
#   'google',
#   'calendar',
#   'provide',
#   'service',
#   'promised',
#   'free',
#   'annual',
#   'subscription',
#   'rate',
#   'dont',
#   'sign',
#   'free',
#   'trial',
#   'worth',
#   'getting',
#   'pinged',
#   'forty',
#   'buck',
#   'decide',
#   'dont',
#   'like',
#   'forget',
#   'cancel',
#   'time',
#   'save',
#   'money'],
#  ['worse'],
#  ['seems',
#   'ok',
#   'basic',
#   'recurring',
#   'task',
#   'need',
#   'work',
#   'actually',
#   'useful',
#   'example',
#   'would',
#   'nice',
#   'able',
#   'set',
#   'task',
#   'recurring',
#   'first',
#   'every',
#   'month',
#   'without',
#   'able',
#   'set',
#   'first',
#   'month',
#   'edit',
#   'also',
#   'noticed',
#   'dark',
#   'theme',
#   'may',
#   'available',
#   'paid',
#   'option',
#   'ill',
#   'never',
#   'know',
#   'since',
#   'basic',
#   'option',
#   'without',
#   'reason',
#   'try',
#   'app',
#   'thus',
#   'never',
#   'pay',
#   'actual',
#   'premium',
#   'option'],
#  ['free',
#   'trial',
#   'canceled',
#   'service',
#   'charged',
#   'anyway',
#   'giving',
#   'way',
#   'contact',
#   'company',
#   'get',
#   'money',
#   'back',
#   'people',
#   'rip',
#   'offs',
#   'didnt',
#   'even',
#   'use',
#   'crappy',
#   'app'],
#  ['reported',
#   'app',
#   'due',
#   'incorrect',
#   'billing',
#   'noone',
#   'answer',
#   'please',
#   'return',
#   'money',
#   'back',
#   'app',
#   'took',
#   'money',
#   'without',
#   'permission',
#   'credit',
#   'card'],
#  ['great',
#   'app',
#   'ruined',
#   'widget',
#   'pay',
#   'premium',
#   'membership',
#   'supposed',
#   'include',
#   'priority',
#   'support',
#   'yet',
#   'customer',
#   'service',
#   'ignoring',
#   'request',
#   'help',
#   'update',
#   'yes',
#   'customer',
#   'support',
#   'responded',
#   'didnt',
#   'solve',
#   'issue',
#   'devs',
#   'great',
#   'listening',
#   'customer',
#   'ive',
#   'switched',
#   'different',
#   'task',
#   'app',
#   'im',
#   'much',
#   'happier',
#   'task',
#   'stephen',
#   'nottage',
#   'check'],
#  ['free'],
#  ['app',
#   'useless',
#   'work',
#   'notepad',
#   'task',
#   'notify',
#   'task',
#   'suppose',
#   'time',
#   'reach',
#   'silent',
#   'doesnt',
#   'pop',
#   'even',
#   'though',
#   'setting',
#   'permitted',
#   'pop',
#   'alert',
#   'even',
#   'simple',
#   'alarm',
#   'clock',
#   'notified',
#   'app',
#   'doesnt',
#   'work'],
#  ['cancel', 'subscription'],
#  ['keep', 'crashing', 'even', 'sign'],
#  ['loaded',
#   'trial',
#   'emailed',
#   'cancelation',
#   'email',
#   'bounced',
#   'back',
#   'ended',
#   'paying',
#   'app',
#   'didnt',
#   'want',
#   'way',
#   'contact',
#   'refund',
#   'careful',
#   'buy',
#   'try',
#   'trial',
#   'youre',
#   'stuck',
#   'paying'],
#  ['thanks',
#   'developer',
#   'quick',
#   'response',
#   'however',
#   'calendar',
#   'useless',
#   'group',
#   'without',
#   'featureswe',
#   'decided',
#   'go',
#   'business',
#   'calendar',
#   'pro',
#   'previous',
#   'comment',
#   'wasnt',
#   'able',
#   'see',
#   'month',
#   'year',
#   'view'],
#  ['hard', 'use'],
#  ['get', 'money', 'back'],
#  ['hate',
#   'company',
#   'make',
#   'needlessly',
#   'create',
#   'account',
#   'star',
#   'review',
#   'payment',
#   'distaste'],
#  ['upgraded', 'lost', 'task', 'previous', 'version', 'disappointed'],
#  ['waste', 'time', 'failed', 'pair', 'mu', 'gmail', 'accountgave', 'attempt'],
#  ['fact',
#   'pay',
#   'much',
#   'use',
#   'something',
#   'simple',
#   'isnt',
#   'worth',
#   'free',
#   'apps',
#   'similar',
#   'functionality'],
#  ['bad', 'ux'],
#  ['good'],
#  ['subscription',
#   'based',
#   'model',
#   'better',
#   'feature',
#   'happy',
#   'pay',
#   'really',
#   'like',
#   'app',
#   'ongoing',
#   'cost',
#   'change',
#   'time'],
#  ['impossible', 'cancel'],
#  ['terrible',
#   'developer',
#   'said',
#   'could',
#   'cancel',
#   'anytime',
#   'believing',
#   'developer',
#   'installed',
#   'refuse',
#   'cancel',
#   'daysafter',
#   'first',
#   'payment',
#   'trickery',
#   'dowbnload'],
#  ['im', 'going', 'even', 'explain', 'one', 'star'],
#  ['want', 'per', 'month', 'thing', 'free', 'google'],
#  ['complicated', 'dislike', 'pro', 'version', 'microft', 'list', 'better'],
#  ['doesnt', 'alarm'],
#  ['deducted',
#   'money',
#   'reason',
#   'used',
#   'service',
#   'never',
#   'used',
#   'return',
#   'money',
#   'immediately'],
#  ['didnt', 'even', 'dare', 'use', 'soon', 'asked', 'per', 'month'],
#  ['confusing', 'navigation'],
#  ['need',
#   'premium',
#   'level',
#   'import',
#   'wunderlist',
#   'b',
#   'reset',
#   'password',
#   'everytime',
#   'login',
#   'havent',
#   'able',
#   'even',
#   'try',
#   'app'],
#  ['great',
#   'application',
#   'lastest',
#   'version',
#   'dont',
#   'notify',
#   'anymore',
#   'event',
#   'reminder',
#   'ill',
#   'uninstall',
#   'application',
#   'useless',
#   'ridiculous',
#   'know',
#   'problem',
#   'dont',
#   'anything',
#   'fix'],
#  ['worried',
#   'security',
#   'access',
#   'email',
#   'facebook',
#   'good',
#   'way',
#   'get',
#   'hack',
#   'information',
#   'stolen'],
#  ['unable', 'subscribe', 'app', 'payment', 'method', 'declined'],
#  ['app',
#   'dont',
#   'even',
#   'deserve',
#   'star',
#   'way',
#   'year',
#   'app',
#   'share',
#   'task',
#   'time',
#   'worth',
#   'secondly',
#   'theme',
#   'fun',
#   'give',
#   'app'],
#  ['app', 'ignores', 'phone', 'dark', 'mode', 'unless', 'pay', 'garbage'],
#  ['close', 'list', 'feature', 'available', 'bin', 'premium', 'mode'],
#  ['one',
#   'worker',
#   'better',
#   'get',
#   'ahold',
#   'within',
#   'next',
#   'hour',
#   'dont',
#   'even',
#   'use',
#   'app',
#   'anymore',
#   'used',
#   'month',
#   'guy',
#   'took',
#   'account',
#   'want',
#   'money'],
#  ['reminding', 'app', 'cannot', 'user', 'friendly'],
#  ['slow',
#   'flow',
#   'turned',
#   'click',
#   'via',
#   'home',
#   'page',
#   'widget',
#   'fade',
#   'effect',
#   'lagging',
#   'please',
#   'kindly',
#   'help',
#   'check',
#   'thank'],
#  ['warning',
#   'malevolent',
#   'app',
#   'feature',
#   'intrusive',
#   'popups',
#   'soon',
#   'unlock',
#   'phone',
#   'without',
#   'even',
#   'activating',
#   'app',
#   'high',
#   'possibility',
#   'crashing',
#   'phone'],
#  ['would',
#   'nice',
#   'know',
#   'price',
#   'using',
#   'data',
#   'download',
#   'uninstalled',
#   'second',
#   'later'],
#  ['worst',
#   'app',
#   'premium',
#   'yearly',
#   'pay',
#   'r',
#   'option',
#   'monthly',
#   'payment',
#   'bad',
#   'app'],
#  ['multiprotocol',
#   'task',
#   'manager',
#   'description',
#   'false',
#   'implies',
#   'front',
#   'end',
#   'service',
#   'couldnt',
#   'get',
#   'past',
#   'first',
#   'screen',
#   'requires',
#   'set',
#   'account',
#   'sync',
#   'use',
#   'private',
#   'server',
#   'capable',
#   'syncing',
#   'thing',
#   'like',
#   'task',
#   'exchange',
#   'public',
#   'cloud',
#   'google',
#   'icloud',
#   'email',
#   'provider',
#   'capability',
#   'therefore',
#   'need',
#   'send',
#   'data',
#   'elsewhere',
#   'already',
#   'server',
#   'fact',
#   'data',
#   'something',
#   'touch',
#   'doesnt',
#   'make',
#   'le',
#   'valuable',
#   'mindful',
#   'valuable',
#   'asset',
#   'today',
#   'may',
#   'tangible',
#   'sure',
#   'quantified',
#   'endlessly',
#   'requiring',
#   'signing',
#   'app',
#   'huge',
#   'red',
#   'flag'],
#  ['free',
#   'trail',
#   'took',
#   'money',
#   'upfront',
#   'install',
#   'angry',
#   '😡',
#   '😡',
#   '😡'],
#  ['trying', 'charge', 'money', 'dont', 'even', 'installed'],
#  ['absolute',
#   'rubbish',
#   'killing',
#   'wunderlist',
#   'clear',
#   'example',
#   'domanant',
#   'power',
#   'big',
#   'thug',
#   'microsoft',
#   'google',
#   'amazon',
#   'etc',
#   'taking',
#   'better',
#   'competitor',
#   'push',
#   'inferior',
#   'garbage',
#   'trying',
#   'ticktock'],
#  ['trying',
#   'anydo',
#   'free',
#   'version',
#   'spent',
#   'quite',
#   'bit',
#   'time',
#   'making',
#   'list',
#   'suddenly',
#   'one',
#   'day',
#   'entirely',
#   'inaccessible',
#   'look',
#   'like',
#   'let',
#   'put',
#   'lot',
#   'dataand',
#   'certain',
#   'point',
#   'decide',
#   'hold',
#   'data',
#   'hostage',
#   'paid',
#   'decided',
#   'use',
#   'anydo',
#   'pay',
#   'started',
#   'making',
#   'list',
#   'would',
#   'suddenly',
#   'didnt',
#   'demand',
#   'paid',
#   'per',
#   'month',
#   'order',
#   'access',
#   'information',
#   'taking',
#   'time',
#   'put'],
#  ['app',
#   'good',
#   'option',
#   'free',
#   'version',
#   'guy',
#   'shouldnt',
#   'label',
#   'app',
#   'free',
#   'wasted',
#   'time',
#   'trying',
#   'app'],
#  ['bad', 'app'],
#  ['one',
#   'app',
#   'free',
#   'description',
#   'press',
#   'continue',
#   'request',
#   '€',
#   'thanks'],
#  ['app',
#   'would',
#   'let',
#   'start',
#   'new',
#   'day',
#   'listed',
#   'task',
#   'performed',
#   'one',
#   'day',
#   'overdue',
#   'next',
#   'day',
#   'weird'],
#  ['originally',
#   'star',
#   'app',
#   'use',
#   'allowing',
#   'access',
#   'either',
#   'email',
#   'facebook',
#   '😡',
#   '😡',
#   '😡',
#   'definitely',
#   'happy',
#   'allow',
#   'deleted',
#   'app',
#   'would',
#   'give',
#   'zero',
#   'star',
#   'could'],
#  ['copied',
#   'google',
#   'calendar',
#   'charging',
#   'top',
#   'google',
#   'calendar',
#   'far',
#   'better'],
#  ['download',
#   'app',
#   'want',
#   'keep',
#   'money',
#   'account',
#   'took',
#   'unauthorized',
#   'almost',
#   'account',
#   'help',
#   'page',
#   'say',
#   'offer',
#   'refund',
#   'within',
#   'hour',
#   'however',
#   'offer',
#   'access',
#   'claim',
#   'refund'],
#  ['provider', 'spam', 'email', 'box', 'option', 'unsubscribe', 'beware'],
#  ['download', 'app', 'aftet', 'update', 'note', 'gone'],
#  ['last', 'update', 'deleted', 'task', 'looking', 'another', 'app'],
#  ['could',
#   'awesome',
#   'app',
#   'great',
#   'potential',
#   'except',
#   'flaw',
#   'end',
#   'making',
#   'super',
#   'irritating',
#   'app',
#   'reported',
#   'issue',
#   'apps',
#   'tech',
#   'support',
#   'several',
#   'time',
#   'get',
#   'lame',
#   'response',
#   'resolution',
#   'latest',
#   'item',
#   'entered',
#   'category',
#   'app',
#   'app',
#   'reason',
#   'resort',
#   'sequence',
#   'item',
#   'list',
#   'automatically',
#   'put',
#   'item',
#   'list',
#   'certain',
#   'order',
#   'reason',
#   'issue',
#   'moreroomher'],
#  ['premium', 'support', 'contacted', 'day', 'counting'],
#  ['hackkk',
#   'tried',
#   'dsnt',
#   'want',
#   'get',
#   'selled',
#   'accpting',
#   'option',
#   'payment',
#   'get',
#   'way',
#   'tried',
#   'debit',
#   'card',
#   'upi',
#   'love',
#   'app',
#   'want',
#   'purchase',
#   'plz',
#   'resolve'],
#  ['charged', 'subscription', 'cancelling', 'trial', 'even', 'using', 'app'],
#  ['doesnt',
#   'sync',
#   'google',
#   'task',
#   'worth',
#   'change',
#   'zapier',
#   'work',
#   'android',
#   'zapier',
#   'work',
#   'pay',
#   'premium',
#   'fee',
#   'plus',
#   'give',
#   'option',
#   'add',
#   'new',
#   'task',
#   'complete',
#   'task',
#   'integrating',
#   'google',
#   'task',
#   'import',
#   'current',
#   'task',
#   'previously',
#   'created',
#   'google',
#   'task',
#   'way',
#   'transfer',
#   'task',
#   'google',
#   'anydo',
#   'cant',
#   'afford',
#   'right',
#   'bat'],
#  ['new',
#   'great',
#   'concept',
#   'confidential',
#   'data',
#   'encrypted',
#   'pw',
#   'protected',
#   'phone',
#   'pc',
#   'one',
#   'day',
#   'anydo',
#   'company',
#   'get',
#   'hacked',
#   'stuff',
#   'like',
#   'equifax',
#   'resolved',
#   'app',
#   'loses',
#   'work',
#   'eg',
#   'created',
#   'new',
#   'task',
#   'started',
#   'note',
#   'section',
#   'pasted',
#   'material',
#   'clicked',
#   'save',
#   'went',
#   'another',
#   'app',
#   'get',
#   'material',
#   'returned',
#   'anydo',
#   'note',
#   'gone',
#   'save',
#   'button',
#   'fraudulent',
#   'save',
#   'clicked'],
#  ['list',
#   'feature',
#   'suck',
#   'dont',
#   'need',
#   'manage',
#   'cant',
#   'speak',
#   'functionality',
#   'wanted',
#   'list',
#   'app',
#   'preferably',
#   'one',
#   'worked',
#   'google',
#   'assistant',
#   'although',
#   'feature',
#   'work',
#   'great',
#   'list',
#   'feature',
#   'kind',
#   'suck',
#   'attempt',
#   'look',
#   'new',
#   'edgy',
#   'user',
#   'experience',
#   'went',
#   'drain',
#   'found',
#   'clunky',
#   'irritating',
#   'shouldnt',
#   'add',
#   'new',
#   'item',
#   'grocery',
#   'list',
#   'able',
#   'uncheck',
#   'item',
#   'need',
#   'thats',
#   'one',
#   'many',
#   'irritation',
#   'anylist',
#   'baby'],
#  ['way',
#   'assign',
#   'specific',
#   'color',
#   'event',
#   'like',
#   'group',
#   'meeting',
#   'color',
#   'cant',
#   'app',
#   'isnt',
#   'useful'],
#  ['hi',
#   'developer',
#   'need',
#   'improve',
#   'note',
#   'module',
#   'fix',
#   'protrait',
#   'view',
#   'im',
#   'using',
#   'landscape',
#   'view',
#   'tablet',
#   'keyboard',
#   'need',
#   'adjust',
#   'head',
#   'gadget',
#   'tq'],
#  ['used',
#   'slick',
#   'minimal',
#   'app',
#   'needed',
#   'kept',
#   'adding',
#   'layer',
#   'unneeded',
#   'feature',
#   'forced',
#   'people',
#   'make',
#   'account',
#   'use',
#   'thanks'],
#  ['theme',
#   'location',
#   'based',
#   'reminder',
#   'subscription',
#   'free',
#   'apps',
#   'like',
#   'thanks',
#   'ill',
#   'pas',
#   'keep',
#   'using',
#   'google',
#   'keep'],
#  ['fine', 'app', 'log', 'every', 'time', 'go', 'use'],
#  ['monthly',
#   'recurring',
#   'reminder',
#   'feature',
#   'cant',
#   'even',
#   'remind',
#   'pay',
#   'bill'],
#  ['cant',
#   'really',
#   'set',
#   'custom',
#   'remindere',
#   'example',
#   'need',
#   'able',
#   'check',
#   'specific',
#   'system',
#   'every',
#   'hour',
#   'variable',
#   'cant'],
#  ['missing',
#   'grocery',
#   'list',
#   'widget',
#   'quantity',
#   'grocery',
#   'list',
#   'item'],
#  ['day',
#   'trialling',
#   'far',
#   'ive',
#   'two',
#   'location',
#   'reminder',
#   'fail',
#   'cant',
#   'label',
#   'location',
#   'one',
#   'letter',
#   'time',
#   'based',
#   'reminder',
#   'thats',
#   'fired',
#   'phone',
#   'call',
#   'dont',
#   'know',
#   'sound',
#   'like',
#   'change',
#   'sound',
#   'anyway',
#   'instruction',
#   'dont',
#   'work',
#   'idea',
#   'button',
#   'meant',
#   'first',
#   'one',
#   'tapped',
#   'task',
#   'got',
#   'snoozed',
#   'hour',
#   'typical',
#   'snooze',
#   'length',
#   'adding',
#   'anything',
#   'basic',
#   'list',
#   'item',
#   'intuitive'],
#  ['select',
#   'weekly',
#   'day',
#   'day',
#   'need',
#   'remainder',
#   'drawback',
#   'app',
#   'best',
#   'go',
#   'app'],
#  ['average',
#   'app',
#   'intuitive',
#   'probably',
#   'spend',
#   'time',
#   'trying',
#   'plan'],
#  ['willing',
#   'give',
#   'try',
#   'see',
#   'suit',
#   'need',
#   'seemed',
#   'ok',
#   'limited',
#   'use',
#   'far',
#   'thing',
#   'annoying',
#   'constant',
#   'notification',
#   'apps',
#   'phone',
#   'vibrates',
#   'anydo',
#   'take',
#   'whole',
#   'screen',
#   'asks',
#   'plan',
#   'day',
#   'dont',
#   'need',
#   'taking',
#   'thing',
#   'plan',
#   'want',
#   'seriously',
#   'equivalent',
#   'browser',
#   'popup',
#   'annoying'],
#  ['made',
#   'account',
#   'app',
#   'long',
#   'time',
#   'ago',
#   'didnt',
#   'use',
#   'long',
#   'forgot',
#   'redownloaded',
#   'today',
#   'one',
#   'apps',
#   'thats',
#   'incredibly',
#   'frustrating',
#   'lot',
#   'main',
#   'advertised',
#   'feature',
#   'behind',
#   'pay',
#   'wall',
#   'andor',
#   'make',
#   'additional',
#   'account',
#   'paying',
#   'list',
#   'app',
#   'ridiculous',
#   'anything',
#   'onetime',
#   'purchase'],
#  ['cant',
#   'clean',
#   'old',
#   'alexa',
#   'list',
#   'use',
#   'purely',
#   'alexa',
#   'shopping',
#   'list',
#   'integration',
#   'however',
#   'early',
#   'buggy',
#   'relink',
#   'alexa',
#   'account',
#   'number',
#   'time',
#   'like',
#   'old',
#   'alexa',
#   'shopping',
#   'list',
#   'cannot',
#   'delete',
#   'alexa',
#   'list',
#   'modified',
#   'anydo',
#   'alexa',
#   'app',
#   'deletes',
#   'working',
#   'one'],
#  ['jump',
#   'wholeheartedly',
#   'using',
#   'app',
#   'integration',
#   'google',
#   'calendar',
#   'exactly',
#   'im',
#   'looking',
#   'see',
#   'search',
#   'feature',
#   'android',
#   'worse',
#   'still',
#   'android',
#   'search',
#   'roadmap',
#   'since',
#   'still',
#   'done',
#   'meantime',
#   'apps',
#   'build',
#   'smart',
#   'list',
#   'tag',
#   'status',
#   'free',
#   'text',
#   'seriously',
#   'behind',
#   'curve',
#   'guy'],
#  ['unable', 'edit', 'time', 'reminder'],
#  ['syncing',
#   'alexa',
#   'take',
#   'minute',
#   'render',
#   'unusable',
#   'anydo',
#   'post',
#   'generic',
#   'response',
#   'yes',
#   'added',
#   'skill',
#   'alexa',
#   'yes',
#   'logged',
#   'account',
#   'syncs',
#   'kind',
#   'verify',
#   'two',
#   'account',
#   'talking',
#   'well',
#   'use',
#   'wunderlist',
#   'google',
#   'task',
#   'alexa',
#   'change',
#   'instantly',
#   'viewable',
#   'across',
#   'platform',
#   'reason',
#   'downloaded',
#   'app',
#   'give',
#   'control',
#   'alexa',
#   'list',
#   'insane',
#   'reason',
#   'cannot',
#   'reorder',
#   'extremely',
#   'lag',
#   'syncing',
#   'anydo',
#   'alexa',
#   'render',
#   'app',
#   'useless',
#   'ui',
#   'look',
#   'really',
#   'nice',
#   'user',
#   'friendly',
#   'bumped',
#   'star'],
#  ['im',
#   'student',
#   'looking',
#   'something',
#   'get',
#   'organized',
#   'tried',
#   'series',
#   'productivity',
#   'apps',
#   'apparently',
#   'one',
#   'feature',
#   'always',
#   'looking',
#   'integration',
#   'apps',
#   'love',
#   'two',
#   'thing',
#   'found',
#   'disappointing',
#   'feature',
#   'extremely',
#   'limited',
#   'without',
#   'premium',
#   'almost',
#   'impossible',
#   'use',
#   'like',
#   'also',
#   'expensive',
#   'couldnt',
#   'find',
#   'statistic',
#   'totally',
#   'hour',
#   'report'],
#  ['paid',
#   'user',
#   'app',
#   'like',
#   'app',
#   'lot',
#   'android',
#   'claim',
#   'used',
#   'possible',
#   'true',
#   'another',
#   'app',
#   'use',
#   'daylio',
#   'nice',
#   'notification',
#   'jump',
#   'like',
#   'anydo',
#   'used',
#   'anydo',
#   'give',
#   'regular',
#   'ignorable',
#   'notification',
#   'click',
#   'app',
#   'something',
#   'screen',
#   'pretty',
#   'pathetic',
#   'give',
#   'notification',
#   'plan',
#   'day',
#   'two',
#   'click',
#   'big',
#   'visual',
#   'pause',
#   'cool',
#   '👎'],
#  ['far',
#   'good',
#   'bit',
#   'expensive',
#   'purchase',
#   'yearly',
#   'basis',
#   'access',
#   'basic',
#   'function',
#   'color',
#   'tag',
#   'come',
#   'translation',
#   'greek',
#   'fluent',
#   'price',
#   'tag',
#   'annually',
#   'would',
#   'apprechiate',
#   'developer',
#   'look',
#   'closer',
#   'give',
#   'try',
#   'committing',
#   'purchasing',
#   'per',
#   'year',
#   'positive',
#   'note',
#   'love',
#   'widget',
#   'using',
#   'however',
#   'nova',
#   'launcher',
#   'current',
#   'rating',
#   'change',
#   'based',
#   'experience'],
#  ['used',
#   'love',
#   'go',
#   'app',
#   'many',
#   'year',
#   'time',
#   'losing',
#   'special',
#   'status',
#   'doesnt',
#   'travel',
#   'time',
#   'anymore',
#   'main',
#   'reason',
#   'could',
#   'stay',
#   'top',
#   'thing',
#   'without',
#   'mentally',
#   'calculate',
#   'meeting',
#   'setting',
#   'time',
#   'removed'],
#  ['good',
#   'shared',
#   'task',
#   'app',
#   'make',
#   'angry',
#   'keep',
#   'forgetting',
#   'logged',
#   'google',
#   'account',
#   'need',
#   'login',
#   'like',
#   'two',
#   'week',
#   'also',
#   'forgets',
#   'setting',
#   'edit',
#   'unfortunately',
#   'fixed',
#   'yet',
#   'even',
#   'though',
#   'sent',
#   'log',
#   'communicated',
#   'decreasing',
#   'rating'],
#  ['create',
#   'account',
#   'check',
#   'functionality',
#   'dont',
#   'want',
#   'uninstalling'],
#  ['liked',
#   'using',
#   'app',
#   'recently',
#   'noticed',
#   'important',
#   'information',
#   'saved',
#   'sub',
#   'task',
#   'deleted',
#   'happened',
#   'thought',
#   'made',
#   'mistake',
#   'app',
#   'malfunctioning'],
#  ['work',
#   'well',
#   'recall',
#   'subscribing',
#   'subscriptioni',
#   'thought',
#   'purchased',
#   'saw',
#   'renewed',
#   'additional',
#   'good',
#   'enough',
#   'justify',
#   'price'],
#  ['allowed',
#   'permission',
#   'app',
#   'still',
#   'cant',
#   'get',
#   'reminder',
#   'work',
#   'smartphone',
#   'running',
#   'android',
#   'downloaded',
#   'different',
#   'reminder',
#   'app',
#   'also',
#   'allowed',
#   'permission',
#   'worked',
#   'well'],
#  ['good',
#   'task',
#   'manager',
#   'like',
#   'misleading',
#   'untrue',
#   'boast',
#   'integration',
#   'm',
#   'outlook',
#   'possible',
#   'via',
#   'zappier',
#   'plus',
#   'functionality',
#   'limited',
#   'possible',
#   'sync',
#   'task'],
#  ['pretty',
#   'nice',
#   'add',
#   'ons',
#   'integration',
#   'ive',
#   'gone',
#   'back',
#   'long',
#   'list',
#   'created',
#   'find',
#   'gone',
#   'reverted',
#   'back',
#   'old',
#   'version',
#   'annoying',
#   'dont',
#   'need',
#   'song',
#   'dance',
#   'app',
#   'offer',
#   'cant',
#   'save',
#   'basic',
#   'list'],
#  ['many',
#   'time',
#   'ive',
#   'put',
#   'sub',
#   'task',
#   'todo',
#   'task',
#   'disappear',
#   'reason',
#   'ive',
#   'forgotten',
#   'many',
#   'thing',
#   'still',
#   'hasnt',
#   'fixed',
#   'despite',
#   'various',
#   'update'],
#  ['love',
#   'app',
#   'recently',
#   'app',
#   'keep',
#   'crashing',
#   'everytime',
#   'enter',
#   'plus',
#   'calendar',
#   'completely',
#   'wrong',
#   '😕'],
#  ['amount',
#   'debited',
#   'renewal',
#   'notice',
#   'option',
#   'app',
#   'cancelation',
#   'auto',
#   'renewal',
#   'dont',
#   'even',
#   'recollect',
#   'option',
#   'auto',
# ...
#   'indeed',
#   'afaik',
#   'doesnt',
#   'ifttt',
#   'applet',
#   'id',
#   'return',
#   'made'],
#  ['app',
#   'really',
#   'amazing',
#   'help',
#   'plan',
#   'day',
#   'ahead',
#   'super',
#   'convenient',
#   'play',
#   'u',
#   'whatever',
#   'planned',
#   'day',
#   'like',
#   'recap',
#   'moment',
#   'thanks'],
#  ['meh',
#   'doesnt',
#   'dark',
#   'mode',
#   'easier',
#   'eye',
#   'thats',
#   'one',
#   'thing',
#   'break'],
#  ['like',
#   'ease',
#   'creating',
#   'different',
#   'list',
#   'ability',
#   'create',
#   'subtasks',
#   'make',
#   'grocery',
#   'shopping',
#   'list',
#   'according',
#   'store',
#   'shop',
#   'great',
#   'grocery',
#   'list',
#   'automatically',
#   'sorted',
#   'aisle',
#   'however',
#   'noticed',
#   'add',
#   'price',
#   'beginning',
#   'end',
#   'grocery',
#   'item',
#   'get',
#   'put',
#   'aisle',
#   'category',
#   'also',
#   'like',
#   'switch',
#   'something',
#   'one',
#   'list',
#   'different',
#   'one',
#   'tapping',
#   'nice',
#   'work',
#   '👍'],
#  ['week',
#   'bad',
#   'somewhat',
#   'intuituve',
#   'like',
#   'app',
#   'far',
#   'thoughtful',
#   'blend',
#   'simplicity',
#   'intuitive',
#   'feature',
#   'go',
#   'beyond',
#   'task',
#   'list',
#   'routine',
#   'habit',
#   'important',
#   'feature',
#   'hard',
#   'find',
#   'change',
#   'initial',
#   'set',
#   'day',
#   'planning',
#   'activity',
#   'anydomoment',
#   'could',
#   'find',
#   'week',
#   'modify',
#   'starting',
#   'important',
#   'step',
#   'difficult',
#   'time',
#   'day',
#   'use',
#   'many',
#   'simmilar',
#   'apps',
#   'aim',
#   'claim',
#   'useful',
#   'achieve',
#   'novelty'],
#  ['someone',
#   'adhd',
#   'organizational',
#   'tool',
#   'necessity',
#   'one',
#   'best',
#   'say',
#   'tried',
#   'every',
#   'well',
#   'rated',
#   'organizational',
#   'app',
#   'app',
#   'store',
#   'said',
#   'obviously',
#   'still',
#   'development',
#   'web',
#   'version',
#   'missing',
#   'many',
#   'important',
#   'aspect',
#   'however',
#   'new',
#   'feature',
#   'coming',
#   'regularly',
#   'team',
#   'responsive',
#   'feature',
#   'par',
#   'namely',
#   'website',
#   'smart',
#   'list',
#   'ill',
#   'changing',
#   'star',
#   'reveiw',
#   'paying',
#   'pro'],
#  ['good'],
#  ['everyone',
#   'would',
#   'productive',
#   'task',
#   'multiple',
#   'notification',
#   'aside',
#   'due',
#   'date',
#   'notification',
#   'hopefully',
#   'youll',
#   'introduce',
#   'next',
#   'update',
#   'thanks'],
#  ['nice'],
#  ['best', 'list', 'app', 'app', 'store'],
#  ['good', 'luck'],
#  ['love',
#   'app',
#   'reminder',
#   'function',
#   'working',
#   'well',
#   'otherwise',
#   'app',
#   'awesome',
#   'plz',
#   'requested',
#   'fix',
#   'soon'],
#  ['u', 'ad', 'sub', 'task', 'home', 'page'],
#  ['awesome',
#   'app',
#   'helpful',
#   'purpose',
#   'well',
#   'wish',
#   'free',
#   'one',
#   'time',
#   'purchase'],
#  ['ad', 'thats', 'nice'],
#  ['platform', 'good', 'platform', 'anything', 'planning', 'used'],
#  ['helpfull', 'apps', 'would', 'great', 'search', 'feature'],
#  ['awesome'],
#  ['list'],
#  ['bit', 'improvement'],
#  ['great'],
#  ['good',
#   'app',
#   'simple',
#   'yet',
#   'add',
#   'layer',
#   'task',
#   'issue',
#   'need',
#   'pay',
#   'feature',
#   'important',
#   'executing',
#   'task'],
#  ['long',
#   'time',
#   'user',
#   'app',
#   'problem',
#   'doesnt',
#   'search',
#   'feature',
#   'cant',
#   'find',
#   'sometimes',
#   'forget',
#   'filed',
#   'note',
#   'task',
#   'longtime',
#   'user',
#   'take',
#   'go',
#   'file',
#   'figure',
#   'title',
#   'heading',
#   'put',
#   'search',
#   'feature',
#   'could',
#   'quickly',
#   'find',
#   'get',
#   'back',
#   'productive',
#   'reason',
#   'gave',
#   'star',
#   'room',
#   'improvement'],
#  ['simple',
#   'use',
#   'make',
#   'list',
#   'easily',
#   'remind',
#   'task',
#   'moment',
#   'thanks'],
#  ['good', 'pay', 'many', 'feature'],
#  ['great'],
#  ['helpful', 'list', 'work'],
#  ['good', 'application', 'better', 'synchronisation', 'time', 'improved'],
#  ['reminder',
#   'popups',
#   'displaying',
#   'bottom',
#   'screen',
#   'new',
#   'samsung',
#   'galaxy',
#   'ultra',
#   'appear',
#   'notification',
#   'area',
#   'top',
#   'screen',
#   'android',
#   'issue',
#   'get',
#   'popups',
#   'worked',
#   'fine',
#   'samsung',
#   'galaxy'],
#  ['widget',
#   'working',
#   'correctly',
#   'updating',
#   'date',
#   'task',
#   'future',
#   'date',
#   'still',
#   'show',
#   'today',
#   'task'],
#  ['exelent', 'sometimes', 'little', 'buggy', 'deleting', 'task', 'daily'],
#  ['good'],
#  ['repetition', 'premium', 'function'],
#  ['pro',
#   'really',
#   'good',
#   'app',
#   'term',
#   'productivity',
#   'usability',
#   'love',
#   'possible',
#   'colour',
#   'code',
#   'label',
#   'task',
#   'eg',
#   'personal',
#   'work',
#   'university',
#   'etc',
#   'love',
#   'syncs',
#   'google',
#   'calendar',
#   'plus',
#   'love',
#   'apps',
#   'ui',
#   'also',
#   'like',
#   'focus',
#   'option',
#   'con',
#   'think',
#   'focus',
#   'option',
#   'like',
#   'forest',
#   'app',
#   'allow',
#   'go',
#   'away',
#   'screentree',
#   'otherwise',
#   'tree',
#   'dy',
#   'also',
#   'think',
#   'able',
#   'add',
#   'attachment',
#   'event',
#   'like',
#   'task'],
#  ['app',
#   'simply',
#   'awesome',
#   '👌',
#   'one',
#   'thing',
#   'missed',
#   'notification',
#   'sound',
#   'wont',
#   'ring',
#   'task',
#   'due',
#   'result',
#   'wont',
#   'able',
#   'know',
#   'task',
#   'aint',
#   'using',
#   'phone'],
#  ['great', 'way', 'stay', 'organized'],
#  ['nice', 'app'],
#  ['testing',
#   'app',
#   'ready',
#   'purchase',
#   'read',
#   'user',
#   'guide',
#   'searching',
#   'task',
#   'available',
#   'android',
#   'know',
#   'would',
#   'available',
#   'also',
#   'one',
#   'time',
#   'fee',
#   'purchase',
#   'option',
#   'gmail',
#   'integration',
#   'feature',
#   'like',
#   'google',
#   'task',
#   'like',
#   'minimalist',
#   'simplistic',
#   'clean',
#   'look',
#   'app',
#   '👍',
#   'nice',
#   'work',
#   'widget',
#   '👍',
#   'thanks',
#   '🙂'],
#  ['like'],
#  ['excellent',
#   'app',
#   'honestly',
#   'life',
#   'would',
#   'disorganised',
#   'without',
#   'really',
#   'help',
#   'stay',
#   'track',
#   'request',
#   'would',
#   'give',
#   'greater',
#   'control',
#   'event',
#   'repeat',
#   'current',
#   'setup',
#   'every',
#   'day',
#   'week',
#   'week',
#   'etc',
#   'eg',
#   'allow',
#   'repeat',
#   'event',
#   'weekday',
#   'even',
#   'better',
#   'specific',
#   'day',
#   'like',
#   'monday',
#   'wednesday',
#   'instance',
#   'otherwise',
#   'app',
#   'sublime',
#   'small',
#   'detail',
#   'added',
#   'see',
#   'reason',
#   'withhold',
#   'start',
#   'reading',
#   'great',
#   'app'],
#  ['nice', 'cost', 'much', 'yearly', 'buy'],
#  ['ideal',
#   'task',
#   'mamager',
#   'perfect',
#   'combination',
#   'ability',
#   'customize',
#   'task',
#   'design',
#   'great',
#   'team',
#   'work',
#   'still',
#   'would',
#   'better',
#   'task',
#   'added',
#   'list',
#   'wouldnt',
#   'automatically',
#   'add',
#   'task',
#   'today',
#   'tomorrow',
#   'etc',
#   'section',
#   'sometimes',
#   'need',
#   'keep',
#   'list',
#   'added',
#   'list',
#   'time',
#   'attachment',
#   'possible',
#   'fan',
#   'forever'],
#  ['good', 'structured'],
#  ['good'],
#  ['app',
#   'service',
#   'best',
#   'expensive',
#   'tap',
#   'subscribe',
#   'yearly',
#   'subscription',
#   'google',
#   'say',
#   'limit',
#   'cross'],
#  ['meh',
#   'doesnt',
#   'dark',
#   'mode',
#   'easier',
#   'eye',
#   'thats',
#   'one',
#   'thing',
#   'break'],
#  ['enough'],
#  ['becoming', 'undispensable', 'fast'],
#  ['beautiful',
#   'design',
#   'id',
#   'prefer',
#   'one',
#   'time',
#   'charge',
#   'option',
#   'pro',
#   'version'],
#  ['need',
#   'easier',
#   'way',
#   'switch',
#   'task',
#   'apps',
#   'specifically',
#   'common',
#   'one',
#   'google',
#   'task',
#   'please',
#   'add',
#   'functionality',
#   'import',
#   'task',
#   'list',
#   'reminder',
#   'event',
#   'logging',
#   'google',
#   'account'],
#  ['may', 'know', 'whats', 'difference', 'app', 'anydo', 'calendar', 'app'],
#  ['good', 'performance', 'far'],
#  ['good'],
#  ['awesome',
#   'app',
#   'love',
#   'simple',
#   'great',
#   'reminder',
#   'system',
#   'one',
#   'big',
#   'thing',
#   'missing',
#   'though',
#   'family',
#   'calender',
#   'shared',
#   'calender',
#   'family',
#   'member',
#   'incisive',
#   'kid',
#   'without',
#   'appphoneemail',
#   'option',
#   'organise',
#   'event',
#   'task',
#   'familymembers'],
#  ['application',
#   'used',
#   'thoroughly',
#   'application',
#   'seriously',
#   'deserves',
#   'star',
#   '✨',
#   'given',
#   'star',
#   'dont',
#   'multiple',
#   'user',
#   'merged',
#   'account',
#   'help',
#   'member',
#   'family',
#   'write',
#   'todo',
#   'single',
#   'place'],
#  ['add', 'long', 'take', 'task', 'instead', 'time', 'task'],
#  ['need',
#   'help',
#   'app',
#   'send',
#   'notification',
#   'task',
#   'even',
#   'put',
#   'time',
#   'go',
#   'allowed',
#   'permission',
#   'smartphone',
#   'configuration'],
#  ['v', 'good', 'complex'],
#  ['super',
#   'good',
#   'anydo',
#   'moment',
#   'longer',
#   'pop',
#   'new',
#   'pixel',
#   'reason',
#   'use',
#   'enabled',
#   'show',
#   'notification',
#   'popup',
#   'get',
#   'working'],
#  ['good',
#   'work',
#   'offline',
#   'love',
#   'one',
#   'improvement',
#   'must',
#   'include',
#   'allow',
#   'u',
#   'hierarchy',
#   'project',
#   'else',
#   'cluttered'],
#  ['change',
#   'letter',
#   'style',
#   'cant',
#   'read',
#   'sub',
#   'title',
#   'double',
#   'line'],
#  ['nothing',
#   'important',
#   'time',
#   'innocently',
#   'surprise',
#   'made',
#   'stronger',
#   '👯'],
#  ['good', 'app'],
#  ['like',
#   'free',
#   'possibility',
#   'arranging',
#   'task',
#   'list',
#   'order',
#   'simple',
#   'clic',
#   'an',
#   'scroll',
#   'order',
#   'home',
#   'screen',
#   'widget',
#   'possibility',
#   'event',
#   'list',
#   'widget',
#   'next',
#   'task',
#   'list',
#   'widget',
#   'event',
#   'list',
#   'also',
#   'show',
#   'task',
#   'seemingly',
#   'appears',
#   'like',
#   'rare',
#   'feature',
#   'event',
#   'list',
#   'task',
#   'list',
#   'integrated',
#   'one',
#   'screen',
#   'dislike',
#   'would',
#   'better',
#   'task',
#   'kept',
#   'prioritisation',
#   'order',
#   'even',
#   'appear',
#   'event',
#   'list'],
#  ['beautifully', 'donelove', 'feature'],
#  ['programming',
#   'language',
#   'used',
#   'develop',
#   'android',
#   'im',
#   'student',
#   'wanna',
#   'build',
#   'apps',
#   'please',
#   'help',
#   'loved',
#   'app',
#   'find',
#   'inspiring'],
#  ['loving',
#   'addition',
#   'would',
#   'able',
#   'view',
#   'highlighted',
#   'task',
#   'event',
#   'calender'],
#  ['good',
#   'app',
#   'know',
#   'exactly',
#   'want',
#   'youll',
#   'need',
#   'app',
#   'get',
#   'started',
#   'lot',
#   'u',
#   'dont',
#   'know',
#   'want',
#   'dont',
#   'lifestyle',
#   'coach',
#   'tell',
#   'u',
#   'improve',
#   'habit',
#   'productive',
#   'seek',
#   'charming',
#   'article',
#   'internet',
#   'maybe',
#   'populate',
#   'internet',
#   'apps',
#   'usability',
#   'behind',
#   'healthyproductive',
#   'living',
#   'theme',
#   'idk',
#   'saying'],
#  ['im',
#   'using',
#   'app',
#   'couple',
#   'year',
#   'really',
#   'nice',
#   'really',
#   'annoying',
#   'reminder',
#   'message',
#   'pop',
#   'type',
#   'message',
#   'call',
#   'hanging'],
#  ['great', 'app'],
#  ['reminder',
#   'dont',
#   'pop',
#   'app',
#   'isnt',
#   'open',
#   'clearing',
#   'open',
#   'tab',
#   'havent',
#   'opened',
#   'day',
#   'think',
#   'thats',
#   'app',
#   'remind',
#   'may',
#   'time',
#   'good',
#   'app',
#   'pls',
#   'id',
#   'like',
#   'worked',
#   'would',
#   'also',
#   'nice',
#   'permit',
#   'option',
#   'pick',
#   'alternating',
#   'day',
#   'week',
#   'frequency',
#   'task',
#   'may',
#   'fall',
#   'weekly',
#   'daily',
#   'eg',
#   'tuesday',
#   'thursday',
#   'saturday'],
#  ['money',
#   'hungry',
#   'devs',
#   'want',
#   'simple',
#   'feature',
#   'thats',
#   'fully',
#   'functional',
#   'organizer',
#   'app',
#   'seems',
#   'nice',
#   'far'],
#  ['helpful'],
#  ['make', 'advanced', 'setting', 'paid', 'subscription', 'color', 'theme'],
#  ['unmatched'],
#  ['link',
#   'amazon',
#   'alexa',
#   'useful',
#   'hated',
#   'typing',
#   'stuff',
#   'ask',
#   'alexa',
#   'add',
#   'stuff',
#   'shopping',
#   'list',
#   'really',
#   'like',
#   'nothing',
#   'wrong',
#   'dont',
#   'like',
#   'typing',
#   'much'],
#  ['perfect',
#   'except',
#   'one',
#   'thing',
#   'want',
#   'button',
#   'bottom',
#   'list',
#   'sometimes',
#   'block',
#   'bottom',
#   'item',
#   'list',
#   'making',
#   'difficult',
#   'cross',
#   'already',
#   'add',
#   'item',
#   'button',
#   'list',
#   'category',
#   'think',
#   'removed',
#   'user',
#   'given',
#   'option',
#   'remove'],
#  ['helpful', 'detailed', 'applove'],
#  ['love',
#   'list',
#   'simple',
#   'useful',
#   'style',
#   'feature',
#   'calendar',
#   'lacking',
#   'bit',
#   'able',
#   'change',
#   'event',
#   'color',
#   'would',
#   'nice',
#   'independent',
#   'note',
#   'instead',
#   'note',
#   'task',
#   'app',
#   'would',
#   'best',
#   'organizer'],
#  ['calendar',
#   'widget',
#   'glitch',
#   'edit',
#   'event',
#   'repeat',
#   'change',
#   'day',
#   'day',
#   'example',
#   'put',
#   'mom',
#   'bday',
#   'jan',
#   'day',
#   'event',
#   'saved',
#   'went',
#   'back',
#   'edit',
#   'repeat',
#   'every',
#   'year',
#   'changed',
#   'jan'],
#  ['okay',
#   'really',
#   'hope',
#   'would',
#   'let',
#   'free',
#   'know',
#   'free',
#   'like',
#   'repeat',
#   'task',
#   'week',
#   'saying',
#   'bad',
#   'excellent',
#   'app'],
#  ['great', 'app'],
#  ['excellent'],
#  ['im', 'waiting', 'window', 'app'],
#  ['nice',
#   'app',
#   'could',
#   'use',
#   'work',
#   'like',
#   'color',
#   'tag',
#   'plan',
#   'day',
#   'feature'],
#  ['keep',
#   'recurring',
#   'task',
#   'free',
#   'reason',
#   'left',
#   'using',
#   'app',
#   'four',
#   'year',
#   'ago',
#   'started',
#   'use',
#   'google',
#   'keep',
#   'everything',
#   'else',
#   'great'],
#  ['cliche',
#   'first',
#   'u',
#   'make',
#   'people',
#   'addicted',
#   'something',
#   'u',
#   'put',
#   'price',
#   'country',
#   'possibility',
#   'purchase',
#   'please',
#   'add',
#   'hijri',
#   'shamsi',
#   'anydos',
#   'calendar',
#   'christian',
#   'month',
#   'name',
#   'calendar',
#   'feature',
#   'recognizable',
#   'persian',
#   'using',
#   'shamsi',
#   'calendar',
#   'month',
#   'name'],
#  ['good'],
#  ['good',
#   'app',
#   'sometimes',
#   'doesnt',
#   'open',
#   'like',
#   'frozen',
#   'go',
#   'force',
#   'stop',
#   'try',
#   'open'],
#  ['really', 'like'],
#  ['great',
#   'app',
#   'planning',
#   'missing',
#   'star',
#   'reminder',
#   'restricted',
#   'personalizable',
#   'want',
#   'reminded',
#   'specific',
#   'hour',
#   'day',
#   'cant'],
#  ['good', 'app', 'many', 'paid', 'service'],
#  ['work', 'lovely'],
#  ['prefering',
#   'google',
#   'calendar',
#   'still',
#   'annoying',
#   'bug',
#   'cant',
#   'editdelete',
#   'event',
#   'added',
#   'calendar',
#   'externally',
#   'gym',
#   'app',
#   'example',
#   'pressing',
#   'edit',
#   'go',
#   'back',
#   'calendar',
#   'view',
#   'instead',
#   'editing'],
#  ['good', 'app', 'need', 'task', 'accepted', 'google', 'calender'],
#  ['good'],
#  ['could', 'type', 'priority'],
#  ['thank',
#   'prompt',
#   'response',
#   'ive',
#   'using',
#   'anydo',
#   'year',
#   'continuing',
#   '😀',
#   'like',
#   'feature',
#   'available',
#   'premium',
#   'option',
#   'im',
#   'subscription',
#   'person',
#   'still',
#   'havent',
#   'seen',
#   'app',
#   'beat',
#   'anydo',
#   '💙'],
#  ['love',
#   'organization',
#   'far',
#   'super',
#   'easy',
#   'use',
#   'even',
#   'comparison',
#   'apps',
#   'like',
#   'would',
#   'make',
#   'one',
#   'change',
#   'would',
#   'like',
#   'able',
#   'click',
#   'specific',
#   'individual',
#   'timedate',
#   'block',
#   'single',
#   'day',
#   'day',
#   'week',
#   'calendar',
#   'set',
#   'add',
#   'specific',
#   'eventtask',
#   'individual',
#   'datetime',
#   'block'],
#  ['overall',
#   'good',
#   'useful',
#   'ill',
#   'likely',
#   'continue',
#   'use',
#   'would',
#   'like',
#   'control',
#   'reminder',
#   'sound',
#   'including',
#   'repeating',
#   'dont',
#   'miss',
#   'sound',
#   'without',
#   'needing',
#   'open',
#   'app',
#   'maybe',
#   'setting',
#   'adjust',
#   'also',
#   'integration',
#   'apps',
#   'including',
#   'trello',
#   'evernote',
#   'general',
#   'multi',
#   'app',
#   'share',
#   'feature',
#   'would',
#   'great',
#   'copying',
#   'reentering',
#   'thing',
#   'multiple',
#   'apps',
#   'want',
#   'send'],
#  ['couple',
#   'day',
#   'generally',
#   'good',
#   'experience',
#   'tie',
#   'nicely',
#   'google',
#   'assistant',
#   'though',
#   'cant',
#   'get',
#   'automatically',
#   'set',
#   'time',
#   'remind',
#   'task',
#   'created',
#   'voice',
#   'slight',
#   'niggle',
#   'certain',
#   'action',
#   'completing',
#   'event',
#   'app',
#   'jump',
#   'mid',
#   'july',
#   'calendar',
#   'clue',
#   'pretty',
#   'irritating',
#   'overall',
#   'seems',
#   'helpful',
#   'productivity'],
#  ['ok', 'far'],
#  ['good', 'app'],
#  ['nice', 'one'],
#  ['good', 'app'],
#  ['im',
#   'enjoying',
#   'user',
#   'interface',
#   'nice',
#   'aesthetic',
#   'importantly',
#   'pretty',
#   'much',
#   'everything',
#   'need',
#   'putting',
#   'task',
#   'however',
#   'widget',
#   'keep',
#   'freezing',
#   'home',
#   'page',
#   'completed',
#   'task',
#   'particular',
#   'day',
#   'dont',
#   'show',
#   'app',
#   'day'],
#  ...]

# %%
w2v_model.build_vocab(documents)

# %%
words = w2v_model.wv.vocab.keys()
vocab_size = len(words)
print("Vocab size", vocab_size)
# Out:
# Vocab size 2341

# %%
print(words)
# Out:
# dict_keys(['update', 'getting', 'response', 'developer', 'would', 'change', 'rating', 'star', 'possible', 'guy', 'hide', 'behind', 'confusing', 'term', 'refuse', 'im', 'annoyed', 'money', 'lost', 'really', 'terrible', 'customer', 'experience', 'original', 'careful', 'signing', 'free', 'trial', 'app', 'happen', 'go', 'automatically', 'charge', 'full', 'year', 'subscription', 'refund', 'ok', 'used', 'fair', 'amount', 'time', 'without', 'problem', 'suddenly', 'asked', 'create', 'account', 'log', 'using', 'google', 'fb', 'one', 'discover', 'everything', 'gone', 'suck', 'good', 'doesnt', 'open', 'close', 'scroll', 'finally', 'show', 'want', 'put', 'list', 'paid', 'garbage', 'seems', 'basic', 'recurring', 'task', 'need', 'work', 'actually', 'useful', 'example', 'nice', 'able', 'set', 'first', 'every', 'month', 'edit', 'also', 'noticed', 'dark', 'theme', 'may', 'available', 'option', 'ill', 'never', 'know', 'since', 'reason', 'try', 'thus', 'pay', 'actual', 'premium', 'absolutely', 'worthless', 'run', 'clunky', 'interface', 'effectively', 'promise', 'calendar', 'provide', 'service', 'promised', 'annual', 'rate', 'dont', 'sign', 'worth', 'buck', 'decide', 'like', 'forget', 'cancel', 'save', 'period', 'scam', 'ive', 'version', 'decided', 'day', 'per', 'ad', 'realized', 'didnt', 'quite', 'organize', 'information', 'best', 'wrote', 'informed', 'must', 'accidentally', 'signed', 'non', 'cannot', 'back', 'nicely', 'intention', 'said', 'buy', 'entire', 'upfront', 'mind', 'due', 'odd', 'behavior', 'reminder', 'youre', 'given', 'hour', 'screwed', 'issue', 'started', 'happening', 'ended', 'obviously', 'read', 'anydo', 'instead', 'helping', 'could', 'awesome', 'great', 'potential', 'except', 'flaw', 'end', 'making', 'super', 'irritating', 'reported', 'apps', 'tech', 'support', 'several', 'get', 'lame', 'resolution', 'latest', 'item', 'entered', 'category', 'certain', 'order', 'felt', 'enough', 'yearly', '€', 'requested', 'week', 'later', 'charged', 'euro', 'credit', 'card', 'feature', 'basically', 'unless', 'gonna', 'keep', 'downloaded', 'login', 'anything', 'logged', 'asking', 'many', 'auto', 'uninstalled', 'still', 'min', 'r', 'kindly', 'useless', 'notify', 'suppose', 'reach', 'silent', 'pop', 'even', 'though', 'setting', 'alert', 'simple', 'alarm', 'clock', 'notified', 'disappointed', 'find', 'functionality', 'recommend', 'sort', 'date', 'properly', 'emailed', 'email', 'paying', 'way', 'contact', 'stuck', 'cant', 'necessary', 'delete', 'redo', 'process', 'running', 'poorly', 'designed', 'thanks', 'quick', 'however', 'group', 'business', 'pro', 'previous', 'comment', 'wasnt', 'see', 'view', 'originally', 'use', 'allowing', 'access', 'either', 'facebook', '😡', 'definitely', 'happy', 'allow', 'deleted', 'give', 'zero', 'couldnt', 'single', 'required', 'monthly', 'greedy', 'hand', 'dev', 'hey', 'something', 'wrong', 'billing', 'please', 'isnt', 'file', 'report', 'play', 'totally', 'avoid', 'expected', 'sudden', 'far', 'incorrect', 'answer', 'return', 'took', 'permission', 'fact', 'much', 'similar', 'level', 'import', 'wunderlist', 'b', 'reset', 'password', 'everytime', 'havent', 'registering', 'address', 'immediate', 'uninstall', 'complicated', 'dislike', 'better', 'bin', 'mode', 'slow', 'turned', 'click', 'via', 'home', 'page', 'widget', 'effect', 'lagging', 'help', 'check', 'thank', 'looked', 'appears', 'trying', 'let', 'start', 'new', 'listed', 'overdue', 'next', 'weird', 'hard', 'decent', 'whole', 'exciting', 'download', 'cheat', 'waste', 'price', 'data', 'second', 'absolute', 'killing', 'clear', 'power', 'big', 'microsoft', 'amazon', 'etc', 'taking', 'competitor', 'push', 'deducted', 'immediately', 'failing', 'repeat', 'daily', 'wont', 'stick', 'sometimes', 'complete', 'figure', 'done', 'uninstalling', 'chore', 'copied', 'charging', 'top', 'contacted', 'counting', 'spam', 'limited', 'changed', 'actively', 'misleading', 'knowing', 'loss', 'worst', 'payment', 'bad', 'scheduled', 'timing', 'make', 'right', 'navigation', 'difficult', 'id', 'say' ...

# %%
# %%time
w2v_model.train(documents, total_examples=len(documents), epochs=W2V_EPOCH)
# Out:
# Wall time: 11.2 s
# (6801735, 8844960)

# %%
w2v_model.most_similar("love")
# Out:
# [('great', 0.5305055379867554),
#  ('awesome', 0.4551678001880646),
#  ('fantastic', 0.4211962819099426),
#  ('amazing', 0.40623319149017334),
#  ('like', 0.4052516222000122),
#  ('perfect', 0.4007713198661804),
#  ('beautiful', 0.3848797380924225),
#  ('enjoy', 0.378772497177124),
#  ('excellent', 0.3749626874923706),
#  ('loved', 0.36299145221710205)]

# %%
vector = w2v_model.wv['update']

# %%
len(vector)
# Out:
# 300

# %% [markdown]
# ### Using Deep Learning

# %%
# Initializing Hyper params

embedding_dim = 300
vocab_size=10000
padding_type='post'
trunc_type='post'
oov_tok = "<OOV>"
max_length=200

# %% [markdown]
# IMPORTANT NOTE:
# - As the given target label which we need to predict is Multi-Label classes, and its mandatory to use the softmax.Before using the softmax lets change the "Y LABEL" by one hot representation.

# %%
y.shape
# Out:
# (15737,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")
print(f"X_test: {X_test.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# X_train: (11015,)
# y_train: (11015,)
# X_test: (4722,)
# y_test: (4722,)

# %%
train_sentences=[]
train_labels=[]
validation_sentences=[]
validation_labels=[]
for i in X_train:
  train_sentences.append(i)

for i in y_train:
  train_labels.append(i)

for i in X_test:
  validation_sentences.append(i)

for i in y_test:
  validation_labels.append(i)

# %%
print(len(train_sentences))
print(len(train_labels))
print(len(validation_sentences))
print(len(validation_labels))
# Out:
# 11015
# 11015
# 4722
# 4722

# %%
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok) 
tokenizer.fit_on_texts(X_train)  
word_index = tokenizer.word_index

train_sequences = tokenizer.texts_to_sequences(X_train) 
train_padded = pad_sequences(train_sequences, padding = padding_type, maxlen=max_length) 
print(len(train_sequences[0]))
print(len(train_padded[0]))
# Out:
# 9
# 200

# %%
print("Length of sequence == ",len(train_sequences))
for i in range(0,10):
    print("sentence: {0}\nsequences: {1} ".format(X_train.iloc[i],train_sequences[i]))
# Out:
# Length of sequence ==  11015
# sentence: dont friggin know yet installed note havent spent time
# sequences: [18, 4027, 111, 250, 382, 115, 333, 547, 4]
# sentence: work linked another calendar appand difficult change time pm
# sequences: [13, 1136, 126, 12, 3391, 465, 54, 4, 1013]
# sentence: اغلب الميزات الهامة مدفوعة
# sequences: [4028, 4029, 4030, 4031]
# sentence: like idea working outlook calendar properly big drawback
# sequences: [5, 123, 91, 312, 12, 337, 281, 1495]
# sentence: jump wholeheartedly using app integration google calendar exactly im looking see search feature android worse still android search roadmap since still done meantime apps build smart list tag status free text seriously behind curve guy
# sequences: [1333, 6120, 35, 2, 313, 38, 12, 417, 27, 116, 41, 451, 15, 140, 742, 50, 140, 451, 3392, 117, 50, 108, 6121, 52, 765, 619, 7, 441, 847, 47, 522, 671, 479, 1381, 345]
# sentence: kind confusing use supposed
# sequences: [321, 314, 6, 583]
# sentence: add task wunderlist
# sequences: [25, 3, 58]
# sentence: noticed notification yesterday reminder disappear really bad wunderlist didnt bug
# sequences: [703, 37, 889, 23, 752, 16, 143, 58, 100, 148]
# sentence: extremely unintuitive
# sequences: [577, 2208]
# sentence: list buy premium get reminder
# sequences: [7, 179, 46, 19, 23]

# %%
validation_sequences = tokenizer.texts_to_sequences(X_test) 
validation_padded = pad_sequences(validation_sequences, padding = padding_type, maxlen=max_length) 

print(len(validation_sequences))
print(validation_padded.shape)
# Out:
# 4722
# (4722, 200)

# %%
y_train1=to_categorical(y_train,num_classes=3)
y_test1=to_categorical(y_test,num_classes=3)
print(y_train1.shape)
print(y_test1.shape)
# Out:
# (11015, 3)
# (4722, 3)

# %%
# label_tokenizer = Tokenizer() 
# label_tokenizer.fit_on_texts(df.Polarity)  

# training_label_seq = np.array(label_tokenizer.texts_to_sequences(train_labels)) 
# validation_label_seq = np.array(label_tokenizer.texts_to_sequences(validation_labels))

# %%
# train_sequences = tokenizer.texts_to_sequences(X_train)
# train_padded= pad_sequences(train_sequences, padding = padding_type, maxlen=max_length)

# %%
# X_train.iloc[0]

# %%
# print("Length of sequence == ",len(train_sequences))
# print("\nSOME COMMON EXAMPLES:")
# for i in range(0,11):
#     print("sentence: {0}\nsequences: {1} ".format(X_train.iloc[i],train_sequences[i]))

# %% [markdown]
# Now lets pad the test data

# %%
# validation_sequences = tokenizer.texts_to_sequences(X_test) 
# validation_padded = pad_sequences(validation_sequences, padding = padding_type, maxlen=max_length) 

# print(len(validation_sequences))
# print(validation_padded.shape)

# %%
## Building an Embedding model
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

model = tf.keras.Sequential([

    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length), 
    tf.keras.layers.LSTM(150, return_sequences=True), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(100),
   
    tf.keras.layers.Dense(256, activation = 'relu'), 
    tf.keras.layers.Dense(3, activation = 'softmax')
    
])
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 200, 300)          3000000
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 200, 150)          270600
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 200, 150)          0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 100)               100400
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               25856
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 3,397,627
# Trainable params: 3,397,627
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# CallBacks
#
# - ReduceLROnPlateau
# - EarlyStopping

# %%
## To avoid overfitting the data we use EarlyStopping

learning_rate_reduction=ReduceLROnPlateau(monitor='val_acc',patience=3,verbose=1,factor=0.5,min_lr=0.00001)
early_stopping= EarlyStopping(monitor='val_loss',min_delta=0, patience=2)
num_epochs = 30
history = model.fit(train_padded,y_train,batch_size=128,epochs=num_epochs,
          validation_split=0.2,callbacks=[learning_rate_reduction,early_stopping])
# Out:
# Train on 8812 samples, validate on 2203 samples
# Epoch 1/30
# 8812/8812 [==============================] - ETA: 0s - loss: 1.0982 - accuracy: 0.3544
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_v1.py:2048: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 8812/8812 [==============================] - 135s 15ms/sample - loss: 1.0982 - accuracy: 0.3544 - val_loss: 1.0973 - val_accuracy: 0.3572
# Epoch 2/30
# 8812/8812 [==============================] - ETA: 0s - loss: 1.0981 - accuracy: 0.3564
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 8812/8812 [==============================] - 143s 16ms/sample - loss: 1.0981 - accuracy: 0.3564 - val_loss: 1.0977 - val_accuracy: 0.3572
# Epoch 3/30
# 8812/8812 [==============================] - ETA: 0s - loss: 1.0975 - accuracy: 0.3591
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 8812/8812 [==============================] - 135s 15ms/sample - loss: 1.0975 - accuracy: 0.3591 - val_loss: 1.0978 - val_accuracy: 0.3572

# %%
### Building An Embedding Model
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

embedding_vector_features=40
model1=Sequential()
model1.add(Embedding(vocab_size, embedding_dim, input_length=max_length))
model1.add(Bidirectional(LSTM(100)))
model1.add(Dropout(0.3))
model1.add(Dense(3, activation = 'softmax'))
model1.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
print(model1.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 200, 300)          3000000
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 200)               320800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 603
# =================================================================
# Total params: 3,321,403
# Trainable params: 3,321,403
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
## To avoid overfitting the data we use EarlyStopping

learning_rate_reduction=ReduceLROnPlateau(monitor='val_acc',patience=5,verbose=1,factor=0.5,min_lr=0.00001)
early_stopping= EarlyStopping(monitor='val_loss',min_delta=0, patience=5)
num_epochs = 30
history = model1.fit(train_padded,y_train1,batch_size=128,epochs=num_epochs,
          validation_split=0.2,callbacks=[learning_rate_reduction,early_stopping])
# Out:
# Train on 8812 samples, validate on 2203 samples
# Epoch 1/30
# 8812/8812 [==============================] - ETA: 0s - loss: 0.9697 - accuracy: 0.5109WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 8812/8812 [==============================] - 155s 18ms/sample - loss: 0.9697 - accuracy: 0.5109 - val_loss: 0.7897 - val_accuracy: 0.6446
# Epoch 2/30
# 8812/8812 [==============================] - ETA: 0s - loss: 0.6921 - accuracy: 0.7049WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 8812/8812 [==============================] - 149s 17ms/sample - loss: 0.6921 - accuracy: 0.7049 - val_loss: 0.7230 - val_accuracy: 0.6886
# Epoch 3/30
# 8812/8812 [==============================] - ETA: 0s - loss: 0.5091 - accuracy: 0.7982WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 8812/8812 [==============================] - 146s 17ms/sample - loss: 0.5091 - accuracy: 0.7982 - val_loss: 0.7516 - val_accuracy: 0.6995
# Epoch 4/30
# 8812/8812 [==============================] - ETA: 0s - loss: 0.3816 - accuracy: 0.8571WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 8812/8812 [==============================] - 143s 16ms/sample - loss: 0.3816 - accuracy: 0.8571 - val_loss: 0.7956 - val_accuracy: 0.7059
# Epoch 5/30
# 8812/8812 [==============================] - ETA: 0s - loss: 0.2910 - accuracy: 0.8925WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 8812/8812 [==============================] - 146s 17ms/sample - loss: 0.2910 - accuracy: 0.8925 - val_loss: 0.8995 - val_accuracy: 0.7068
# Epoch 6/30
# 8812/8812 [==============================] - ETA: 0s - loss: 0.2293 - accuracy: 0.9158WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 8812/8812 [==============================] - 147s 17ms/sample - loss: 0.2293 - accuracy: 0.9158 - val_loss: 1.0184 - val_accuracy: 0.7190
# Epoch 7/30
# 8812/8812 [==============================] - ETA: 0s - loss: 0.1930 - accuracy: 0.9302WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 8812/8812 [==============================] - 150s 17ms/sample - loss: 0.1930 - accuracy: 0.9302 - val_loss: 0.9705 - val_accuracy: 0.7227

# %%
# %%time
score = model1.evaluate(validation_padded, y_test1, batch_size=128)
print()
print("ACCURACY:",score[1])
print("LOSS:",score[0])
# Out:
# ACCURACY: 0.72384584
# LOSS: 0.9413640134569853
# Wall time: 13.4 s

# %%
predict=np.argmax(model1.predict(validation_padded), axis=-1)
predict
# Out:
# array([0, 2, 1, ..., 1, 0, 0], dtype=int64)

# %%
#plotting confusion matrix
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.YlOrRd):
    """
    See full source and example: 
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
    
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title,fontsize=17)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=0)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="right",
                 color="White" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
import itertools
plt.figure(figsize=(7,7))
cm = confusion_matrix(y_test,predict)
plot_confusion_matrix(cm, classes=['Negative','Neutral','Positive'])
plt.savefig("confusion_matrix.jpg")
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,predict)
# Out:
# 0.7238458280389666

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76      1518
#            1       0.64      0.64      0.64      1495
#            2       0.76      0.78      0.77      1709
#
#     accuracy                           0.72      4722
#    macro avg       0.72      0.72      0.72      4722
# weighted avg       0.72      0.72      0.72      4722

# %%
fig=plt.figure(figsize=(10,5))
plt.title("MODEL PERFORMANCE DURING TRAINING AND EVALUATION")
fig1=fig.add_subplot(121)
plt.plot(history.history['accuracy'],color='Green')
plt.plot(history.history["val_accuracy"],color='red')
# plt.ylim(0.90, 1.05)
plt.xlabel("epoch")
plt.ylabel("accuracies")
plt.legend(['Train accuracy','Validation Accuracy'])

fig2=fig.add_subplot(122)
plt.plot(history.history["loss"],color='g')
plt.plot(history.history["val_loss"],color='r')
# plt.ylim(0.0, 1)
plt.xlabel("epoch")
plt.ylabel("Losses")
plt.legend(['Train_Loss','Val_Loss'])

plt.savefig("Model Performance.jpg")
plt.show()

# %%
actual=pd.DataFrame({"Actual":list(y_test),"Predicted":list(predict)})
actual.head()
# Out:
#    Actual  Predicted
# 0       0          0
# 1       2          2
# 2       1          1
# 3       1          1
# 4       1          1

# %%
actual_list_test=list(X_test)
lis=df.loc[df["clean_text"].isin(actual_list_test)].reset_index(drop=True)
lis.drop(["common_words"],1,inplace=True)

# %%
X_test.iloc[0]
# Out:
# 'cant rely reminder alarm come even select alarm relying app missed important task'

# %%
y_test.iloc[0]
# Out:
# 0

# %%
predict[0]
# Out:
# 0

# %%
get_X_test=[]
actual_label=[]
predict_label=[]
for i in range(len(X_test)):
    get_X_test.append(X_test.iloc[i])
    actual_label.append(y_test.iloc[i])
    predict_label.append(predict[i])

# %%
tuple_list=list(zip(get_X_test,actual_label,predict_label))

# %%
conclude=pd.DataFrame(data=tuple_list,columns=["text","Actual","Predicted"])

# %%
conclude.head(50)
# Out:
#                                                  text  Actual  Predicted
# 0   cant rely reminder alarm come even select alar...       0          0
# 1   great app almost providing everything want fre...       2          2
# 2                                                 yas       1          1
# 3   like app lot refreshing star flexibility setti...       1          1
# 4   edit reverted old version something issue back...       1          1
# 5   app phone ipad communicate everything input ph...       1          1
# 6   app allready great amount customisation surrea...       2          2
# 7   ребят конечно круто что вы сделали это в виде ...       1          1
# 8   cool concept sync doesnt work desktop addon ha...       0          0
# 9   app haas hekped changed life definitely recommend       2          2
# 10  work expected would like time customisation fl...       2          2
# 11                                            ad many       0          0
# 12  nice app super helpful plan anything recommend...       2          2
# 13  far good love creating adventure still learnin...       2          2
# 14                  task notification stopped working       0          0
# 15     pity task become overdue according system time       1          1
# 16  app ok could much better term usability exampl...       1          1
# 17                                           easy use       2          2
# 18  started using year ago quickly became fixture ...       2          2
# 19  vanilla habitician game failed serve purpose s...       2          2
# 20  searched quite time find calendar app wife cou...       2          2
# 21  love app would give star review except cant ge...       1          1
# 22                                         habit free       1          2
# 23                              clunky inflexible job       1          0
# 24  love app change wish would make certain word n...       2          2
# 25  since last major update rescheduling task take...       0          0
# 26                             bad still new user tho       1          1
# 27  immediately encountered problem began misclick...       0          0
# 28            wonderful app must took lot effort make       2          2
# 29  good would like completed task automatically m...       1          1
# 30  awesome except widget randomly annoyingly ofte...       1          1
# 31  however bug every often one recurring task app...       2          2
# 32  fix glitch want change streak daily keyboard p...       1          2
# 33  installed trial version use use end surprise s...       0          0
# 34  doesnt seem possible delete single event serie...       1          1
# 35  problem purchasing pro version click buy pro b...       0          0
# 36                           great intuitive easy use       2          2
# 37  give feature par google keep dark mode essenti...       2          2
# 38  like app idea dont know since app working back...       1          1
# 39  functionality seamless feature order task cust...       2          1
# 40                                           feel old       0          0
# 41   exactly looking way set visualize weekly routine       2          2
# 42  dude dont want people pay u everything come xx...       0          0
# 43  great color list note sublists lot option terr...       1          2
# 44  coming wunderlist started import importing day...       0          0
# 45  nice little app liked aspect uninstall one fea...       0          1
# 46  app incredibly helpful need take medication ev...       2          2
# 47  also looking change year usage app stooping ad...       0          0
# 48                                               good       1          2
# 49  love app big procrastinater make much organize...       2          2

# %%
lis=df.loc[df["clean_text"].isin(list(conclude.text))].reset_index(drop=True)
lis.head()
# Out:
#          userName                                            content  \
# 0   Scott Prewitt  Absolutely worthless. This app runs a prohibit...
# 1      Chris Lane  BEWARE the trial period is a scam I've been us...
# 2       John Papp  DON'T BUY PREMIUM! You have to pay for an enti...
# 3  Jason Thornton  This could be an awesome app. It has great pot...
# 4    Ernie Nadeau  Loaded the trial then emailed about cancelatio...
#
#    Polarity                                         clean_text  \
# 0         0  absolutely worthless app run prohibitively clu...
# 1         0  beware trial period scam ive using free versio...
# 2         0  dont buy premium pay entire year upfront chang...
# 3         0  could awesome app great potential except flaw ...
# 4         0  loaded trial emailed cancelation email bounced...
#
#                                         common_words
# 0  ['absolutely', 'worthless', 'app', 'run', 'pro...
# 1  ['beware', 'trial', 'period', 'scam', 'ive', '...
# 2  ['dont', 'buy', 'premium', 'pay', 'entire', 'y...
# 3  ['could', 'awesome', 'app', 'great', 'potentia...
# 4  ['loaded', 'trial', 'emailed', 'cancelation', ...

# %%
# %%time
dfi=pd.merge(conclude,lis,left_on='text',right_on='clean_text',how='inner',indicator=True)
# Out:
# Wall time: 34.9 ms

# %%
conclude_data=dfi.drop(["userName","text","Polarity","clean_text","common_words","_merge"],1)
sample_data = conclude_data.sample(frac = 1) 
sample_data.head()
# Out:
#        Actual  Predicted                                            content
# 13377       2          2  I love how I can write done everything and it ...
# 7310        2          2                                         It's great
# 1798        2          2                                               Good
# 3764        1          2                                               good
# 3131        2          2                                               Good

# %%
sample_data1 = conclude_data.sample(frac = 0.8) 
sample_data1.head()
# Out:
#        Actual  Predicted                                            content
# 11124       2          2  Very good Well, it's a great app. I just wish ...
# 6487        0          2                                               Good
# 357         1          2                                               good
# 15212       1          0  Good app. Minus one star because of the consta...
# 2987        0          2                                               Good

# %%
def function(col):
    if col==0:
        return "Negative"
    elif col==2:
        return "Positive"
    else:
        return "Neutral"

# %%
sample_data1["Actual"]=sample_data1["Actual"].apply(function)
sample_data1["Predicted"]=sample_data1["Predicted"].apply(function)
sample_data1.reset_index(drop=True,inplace=True)
sample_data1 = sample_data1.reindex(columns=['content',"Actual","Predicted"])
sample_data1.head(10)
# Out:
#                                              content    Actual Predicted
# 0  Very good Well, it's a great app. I just wish ...  Positive  Positive
# 1                                               Good  Negative  Positive
# 2                                               good   Neutral  Positive
# 3  Good app. Minus one star because of the consta...   Neutral  Negative
# 4                                               Good  Negative  Positive
# 5  Too complicated when putting on data. I'll sta...  Negative  Negative
# 6  I bought the premium. And I can't sync the dat...  Negative  Negative
# 7  Really unimpressed that I cannot get notificat...  Negative   Neutral
# 8  The app itself is really great. However, if yo...   Neutral   Neutral
# 9                                               Good   Neutral  Positive

# %%
sample_data1.to_csv("submit_list.csv")

# %% [markdown]
# ## Applying Third Model

# %%
model2= Sequential()

model2.add(Embedding(vocab_size, embedding_dim, input_length=max_length))  #(# Your Embedding Layer)
model2.add(Bidirectional(LSTM(150, return_sequences=True)))  #(# An LSTM Layer)
model2.add(Dropout(0.2))  #(# A dropout layer)
model2.add(LSTM(100))  #(# Another LSTM Layer)
model2.add(Dropout(0.2))  #(# A dropout layer)
model2.add(Dense(256, activation='relu'))  #(# A Dense Layer including regularizers)
model2.add(Dense(3, activation='softmax')) 


model2.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
print(model2.summary())
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 200, 300)          3000000
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 200, 300)          541200
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 200, 300)          0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 100)               160400
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               25856
# _________________________________________________________________
# dense_13 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 3,728,227
# Trainable params: 3,728,227
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
## To avoid overfitting the data we use EarlyStopping
# %%time
learning_rate_reduction=ReduceLROnPlateau(monitor='val_acc',patience=5,verbose=1,factor=0.5,min_lr=0.00001)
early_stopping= EarlyStopping(monitor='val_loss',min_delta=0, patience=5)
num_epochs = 30
history = model2.fit(train_padded,y_train,batch_size=128,epochs=num_epochs,
          validation_split=0.2,callbacks=[learning_rate_reduction,early_stopping])
# Out:
# Epoch 1/30
# 69/69 [==============================] - ETA: 0s - loss: 1.0970 - accuracy: 0.3609WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 69/69 [==============================] - 7s 102ms/step - loss: 1.0970 - accuracy: 0.3609 - val_loss: 1.0975 - val_accuracy: 0.3572
# Epoch 2/30
# 69/69 [==============================] - ETA: 0s - loss: 1.0969 - accuracy: 0.3609WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 69/69 [==============================] - 7s 102ms/step - loss: 1.0969 - accuracy: 0.3609 - val_loss: 1.0977 - val_accuracy: 0.3572
# Epoch 3/30
# 69/69 [==============================] - ETA: 0s - loss: 1.0970 - accuracy: 0.3609WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 69/69 [==============================] - 7s 101ms/step - loss: 1.0970 - accuracy: 0.3609 - val_loss: 1.0976 - val_accuracy: 0.3572
# Epoch 4/30
# 69/69 [==============================] - ETA: 0s - loss: 1.0968 - accuracy: 0.3609WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 69/69 [==============================] - 7s 102ms/step - loss: 1.0968 - accuracy: 0.3609 - val_loss: 1.0973 - val_accuracy: 0.3572
# Epoch 5/30
# 69/69 [==============================] - ETA: 0s - loss: 1.0968 - accuracy: 0.3609WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 69/69 [==============================] - 7s 101ms/step - loss: 1.0968 - accuracy: 0.3609 - val_loss: 1.0977 - val_accuracy: 0.3572
# Epoch 6/30
# 69/69 [==============================] - ETA: 0s - loss: 1.0968 - accuracy: 0.3609WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 69/69 [==============================] - 7s 101ms/step - loss: 1.0968 - accuracy: 0.3609 - val_loss: 1.0975 - val_accuracy: 0.3572
# Epoch 7/30
# 69/69 [==============================] - ETA: 0s - loss: 1.0971 - accuracy: 0.3609WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 69/69 [==============================] - 7s 101ms/step - loss: 1.0971 - accuracy: 0.3609 - val_loss: 1.0975 - val_accuracy: 0.3572
# Epoch 8/30
# 69/69 [==============================] - ETA: 0s - loss: 1.0969 - accuracy: 0.3608WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 69/69 [==============================] - 7s 101ms/step - loss: 1.0969 - accuracy: 0.3608 - val_loss: 1.0974 - val_accuracy: 0.3572
# Epoch 9/30
# 69/69 [==============================] - ETA: 0s - loss: 1.0971 - accuracy: 0.3609WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 69/69 [==============================] - 7s 101ms/step - loss: 1.0971 - accuracy: 0.3609 - val_loss: 1.0978 - val_accuracy: 0.3572
# CPU times: user 57.7 s, sys: 2.94 s, total: 1min
# Wall time: 1min 3s

# %%
# %%time
score = model1.evaluate(validation_padded, y_test, batch_size=128)
print()
print("ACCURACY:",score[1])
print("LOSS:",score[0])
# Out:
# 37/37 [==============================] - 1s 23ms/step - loss: 1.4792 - accuracy: 0.7145
#
# ACCURACY: 0.7145277261734009
# LOSS: 1.479239821434021
# CPU times: user 624 ms, sys: 39.8 ms, total: 664 ms
# Wall time: 939 ms

# %%
fig=plt.figure(figsize=(10,5))

fig1=fig.add_subplot(121)
plt.plot(history.history['accuracy'],color='Green')
plt.plot(history.history["val_accuracy"],color='red')
# plt.ylim(0.90, 1.05)
plt.xlabel("epoch")
plt.ylabel("accuracies")
plt.legend(['Train accuracy','Validation Accuracy'])

fig2=fig.add_subplot(122)
plt.plot(history.history["loss"],color='g')
plt.plot(history.history["val_loss"],color='r')
# plt.ylim(0.0, 1)
plt.xlabel("epoch")
plt.ylabel("Losses")
plt.legend(['Train_Loss','Val_Loss'])
plt.show()
